# %% [markdown]
# **Download YOLOV5 Github Repo**

# %%
# !cp /kaggle/input/load-gdcm-in-notebook-without-internet/gdcm.tar .
# !tar -xvzf gdcm.tar
# !conda install --offline /kaggle/input/load-gdcm-in-notebook-without-internet/gdcm/gdcm-2.8.9-py37h71b2a6d_0.tar.bz2
# !rm -rf /kaggle/working/gdcm.tar
# Out:
# gdcm/
# gdcm/conda-4.8.4-py37hc8dfbb8_2.tar.bz2
# gdcm/gdcm-2.8.9-py37h71b2a6d_0.tar.bz2
# gdcm/libjpeg-turbo-2.0.3-h516909a_1.tar.bz2
#
# Downloading and Extracting Packages
# ######################################################################## | 100%
# done
# done
# done

# %% [markdown]
# **Import necessary packages**

# %%
import os
import cv2
import yaml
import torch
import pandas as pd
from PIL import Image
from torch.utils.data import DataLoader
import numpy as np
import pydicom
from tqdm.notebook import tqdm
from pydicom.pixel_data_handlers.util import apply_voi_lut
import torch.nn.functional as F
from albumentations import Compose, Normalize, Resize, HorizontalFlip, RandomBrightnessContrast, ShiftScaleRotate, IAAAdditiveGaussianNoise, RandomCrop
from albumentations.pytorch import ToTensorV2
from efficientnet import EfficientNet

# %%
def dicom2array(path, voi_lut=True, fix_monochrome=True):
    """ Convert dicom file to numpy array 
    
    Args:
        path (str): Path to the dicom file to be converted
        voi_lut (bool): Whether or not VOI LUT is available
        fix_monochrome (bool): Whether or not to apply monochrome fix
        
    Returns:
        Numpy array of the respective dicom file 
        
    """
    # Use the pydicom library to read the dicom file
    dicom = pydicom.read_file(path)
    
    # VOI LUT (if available by DICOM device) is used to 
    # transform raw DICOM data to "human-friendly" view
    if voi_lut:
        data = apply_voi_lut(dicom.pixel_array, dicom)
    else:
        data = dicom.pixel_array
        
    # The XRAY may look inverted
    #   - If we want to fix this we can
    if fix_monochrome and dicom.PhotometricInterpretation == "MONOCHROME1":
        data = np.amax(data) - data
    
    # Normalize the image array and return
    data = data - np.min(data)
    data = data / np.max(data)
    data = (data * 255).astype(np.uint8)
    return data

# %% [markdown]
# **Prepare test dataframe**

# %%
test_meta_df = pd.DataFrame(columns=["image_id", "study_id", "dcm_path", "width", "height"])
os.makedirs('/kaggle/covid19_test_images', exist_ok=True)
images, studies, dcm_path, widths, heights = [], [], [], [], []
tk = tqdm(enumerate(os.listdir('/kaggle/input/siim-covid19-detection/test')), total=len(os.listdir('/kaggle/input/siim-covid19-detection/test')))
for _, study in tk:#os.listdir('/kaggle/input/siim-covid19-detection/test'):
    for serie in os.listdir('/kaggle/input/siim-covid19-detection/test/{}'.format(study)):
        for image in os.listdir('/kaggle/input/siim-covid19-detection/test/{}/{}'.format(study, serie)):
            images.append(image)
            studies.append(study)
            dcm_path.append('/kaggle/input/siim-covid19-detection/test/{}/{}/{}'.format(study, serie, image))
            
            arr = dicom2array(dcm_path[-1])
            arr = np.stack((arr, arr, arr), axis=-1)
            im = Image.fromarray(arr)
            im.save("/kaggle/covid19_test_images/{}".format(image.replace("dcm", "jpg")))
            
            widths.append(arr.shape[1])
            heights.append(arr.shape[0])
            
test_meta_df["image_id"]=images
test_meta_df["study_id"]=studies
test_meta_df["dcm_path"]=dcm_path
test_meta_df["width"]=widths
test_meta_df["height"]=heights
# Out:
#   0%|          | 0/1214 [00:00<?, ?it/s]

# %%
#Save dicom data to JPEG 
os.makedirs('/kaggle/covid19_test_images', exist_ok=True)
tk = tqdm(enumerate(os.listdir('/kaggle/input/siim-covid19-detection/test')), total=len(os.listdir('/kaggle/input/siim-covid19-detection/test')))
for i, study in tk:
    for serie in os.listdir('/kaggle/input/siim-covid19-detection/test/{}'.format(study)):
        for img in os.listdir('/kaggle/input/siim-covid19-detection/test/{}/{}'.format(study, serie)):
            arr = dicom2array("/kaggle/input/siim-covid19-detection/test/{}/{}/{}".format(study, serie, img))
            arr = np.stack((arr, arr, arr), axis=-1)
            im = Image.fromarray(arr)
            im.save("/kaggle/covid19_test_images/{}.jpg".format(img[:-4]))
# Out:
#   0%|          | 0/1214 [00:00<?, ?it/s]

# %%
TEST_PATH = '/kaggle/covid19_test_images'
os.makedirs('/kaggle/working/output', exist_ok=True)

# %%
MODEL_PATH = '/kaggle/input/multi-class-model/singlecls_100ep.pt'
# !python /kaggle/input/yolov5code/yolov5-master/detect.py --weights {MODEL_PATH} \
                                                          --source {TEST_PATH} \
                                                          --img 256 \
                                                          --conf-thres 0.323 \
                                                          --iou-thres 0.5 \
                                                          --max-det 5 \
                                                          --save-txt \
                                                          --save-conf \
                                                          --project '/kaggle/working/output' \
                                                          --nosave \
                                                          --name ""\
                                                          --exist-ok \
                                                          --device "0"
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.323, device='0', exist_ok=True, half=False, hide_conf=False, hide_labels=False, imgsz=256, iou_thres=0.5, line_thickness=3, max_det=5, name='', nosave=True, project='/kaggle/working/output', save_conf=True, save_crop=False, save_txt=True, source='/kaggle/covid19_test_images', update=False, view_img=False, weights=['/kaggle/input/multi-class-model/singlecls_100ep.pt'])
# requirements: /kaggle/working/requirements.txt not found, check failed.
# image 1/1263 /kaggle/covid19_test_images/0026720152f5.jpg: 256x256 Done. (0.040s)
# image 2/1263 /kaggle/covid19_test_images/00fc8fc35dc1.jpg: 256x224 2 opacitys, Done. (0.044s)
# image 3/1263 /kaggle/covid19_test_images/01c3512eebc3.jpg: 256x256 Done. (0.028s)
# image 4/1263 /kaggle/covid19_test_images/01f948f8e544.jpg: 256x256 Done. (0.027s)
# image 5/1263 /kaggle/covid19_test_images/022146012034.jpg: 256x256 Done. (0.026s)
# image 6/1263 /kaggle/covid19_test_images/02eceb0fc405.jpg: 224x256 Done. (0.036s)
# image 7/1263 /kaggle/covid19_test_images/03a778f5a68b.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 8/1263 /kaggle/covid19_test_images/03fa9d7e94a8.jpg: 256x256 Done. (0.027s)
# image 9/1263 /kaggle/covid19_test_images/040d0765b661.jpg: 256x256 Done. (0.027s)
# image 10/1263 /kaggle/covid19_test_images/0418a303883e.jpg: 256x256 Done. (0.026s)
# image 11/1263 /kaggle/covid19_test_images/042979d394a1.jpg: 224x256 Done. (0.027s)
# image 12/1263 /kaggle/covid19_test_images/04396dd5af2f.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 13/1263 /kaggle/covid19_test_images/045c1e859dfa.jpg: 256x256 Done. (0.026s)
# image 14/1263 /kaggle/covid19_test_images/046b1edf6801.jpg: 224x256 Done. (0.027s)
# image 15/1263 /kaggle/covid19_test_images/04720d7e4e42.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 16/1263 /kaggle/covid19_test_images/047ba804182b.jpg: 256x256 Done. (0.027s)
# image 17/1263 /kaggle/covid19_test_images/049fce8128f9.jpg: 224x256 1 opacity, Done. (0.027s)
# image 18/1263 /kaggle/covid19_test_images/04a083828fec.jpg: 224x256 Done. (0.025s)
# image 19/1263 /kaggle/covid19_test_images/04de800ea41a.jpg: 224x256 Done. (0.026s)
# image 20/1263 /kaggle/covid19_test_images/04f4a36c08a2.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 21/1263 /kaggle/covid19_test_images/05435da60872.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 22/1263 /kaggle/covid19_test_images/0562436fde50.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 23/1263 /kaggle/covid19_test_images/059eae61ad15.jpg: 224x256 Done. (0.027s)
# image 24/1263 /kaggle/covid19_test_images/05a70a1c16c1.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 25/1263 /kaggle/covid19_test_images/05ab2c886dc1.jpg: 256x256 Done. (0.026s)
# image 26/1263 /kaggle/covid19_test_images/05e168e0d636.jpg: 256x256 Done. (0.026s)
# image 27/1263 /kaggle/covid19_test_images/05feea9719f5.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 28/1263 /kaggle/covid19_test_images/064b37b01cd2.jpg: 224x256 Done. (0.026s)
# image 29/1263 /kaggle/covid19_test_images/06abdb2562ce.jpg: 256x256 Done. (0.028s)
# image 30/1263 /kaggle/covid19_test_images/06df1e2fde68.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 31/1263 /kaggle/covid19_test_images/070cbe2d3dbb.jpg: 224x256 Done. (0.040s)
# image 32/1263 /kaggle/covid19_test_images/0718c860f2ee.jpg: 224x256 Done. (0.037s)
# image 33/1263 /kaggle/covid19_test_images/079be2a10982.jpg: 224x256 Done. (0.036s)
# image 34/1263 /kaggle/covid19_test_images/07c552c36da3.jpg: 224x256 Done. (0.039s)
# image 35/1263 /kaggle/covid19_test_images/07db3756ec28.jpg: 224x256 2 opacitys, Done. (0.030s)
# image 36/1263 /kaggle/covid19_test_images/07eb8cf8958a.jpg: 256x256 Done. (0.027s)
# image 37/1263 /kaggle/covid19_test_images/0821e77a60ed.jpg: 224x256 Done. (0.028s)
# image 38/1263 /kaggle/covid19_test_images/087f2e308700.jpg: 224x256 Done. (0.026s)
# image 39/1263 /kaggle/covid19_test_images/08992bd07010.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 40/1263 /kaggle/covid19_test_images/08b12b305a50.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 41/1263 /kaggle/covid19_test_images/08bbffaafbe7.jpg: 224x256 1 opacity, Done. (0.028s)
# image 42/1263 /kaggle/covid19_test_images/09443dcb865f.jpg: 256x256 Done. (0.027s)
# image 43/1263 /kaggle/covid19_test_images/09a38ab5a5bd.jpg: 256x256 Done. (0.026s)
# image 44/1263 /kaggle/covid19_test_images/09b64291b1b9.jpg: 256x256 Done. (0.026s)
# image 45/1263 /kaggle/covid19_test_images/0a0c1312be06.jpg: 224x256 1 opacity, Done. (0.029s)
# image 46/1263 /kaggle/covid19_test_images/0a3a99612b28.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 47/1263 /kaggle/covid19_test_images/0af6a45668be.jpg: 224x256 Done. (0.026s)
# image 48/1263 /kaggle/covid19_test_images/0bbb78f96f46.jpg: 256x256 Done. (0.026s)
# image 49/1263 /kaggle/covid19_test_images/0be236941397.jpg: 224x256 Done. (0.028s)
# image 50/1263 /kaggle/covid19_test_images/0c2ad4c7a6c4.jpg: 256x256 Done. (0.027s)
# image 51/1263 /kaggle/covid19_test_images/0c4d32f6b806.jpg: 224x256 Done. (0.027s)
# image 52/1263 /kaggle/covid19_test_images/0c81b34981b3.jpg: 256x256 Done. (0.027s)
# image 53/1263 /kaggle/covid19_test_images/0c8af80ba8cb.jpg: 224x256 1 opacity, Done. (0.028s)
# image 54/1263 /kaggle/covid19_test_images/0cc69a8f538c.jpg: 224x256 3 opacitys, Done. (0.028s)
# image 55/1263 /kaggle/covid19_test_images/0cccb1eca1fc.jpg: 224x256 Done. (0.029s)
# image 56/1263 /kaggle/covid19_test_images/0cea7e93db89.jpg: 224x256 1 opacity, Done. (0.028s)
# image 57/1263 /kaggle/covid19_test_images/0d47ef3e87e4.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 58/1263 /kaggle/covid19_test_images/0d4ba5dc4a24.jpg: 224x256 Done. (0.026s)
# image 59/1263 /kaggle/covid19_test_images/0d50bce86451.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 60/1263 /kaggle/covid19_test_images/0d617e83e527.jpg: 224x256 Done. (0.027s)
# image 61/1263 /kaggle/covid19_test_images/0db323463d0a.jpg: 256x256 Done. (0.028s)
# image 62/1263 /kaggle/covid19_test_images/0dc27df9b1bf.jpg: 224x256 Done. (0.027s)
# image 63/1263 /kaggle/covid19_test_images/0e97cc4123aa.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 64/1263 /kaggle/covid19_test_images/0ed283a366dc.jpg: 224x256 Done. (0.027s)
# image 65/1263 /kaggle/covid19_test_images/0f01c0517022.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 66/1263 /kaggle/covid19_test_images/0f147ee4a61b.jpg: 224x256 1 opacity, Done. (0.027s)
# image 67/1263 /kaggle/covid19_test_images/0f50aabaa314.jpg: 224x256 Done. (0.026s)
# image 68/1263 /kaggle/covid19_test_images/0f813cc26e33.jpg: 224x256 Done. (0.026s)
# image 69/1263 /kaggle/covid19_test_images/0feac35cd28b.jpg: 224x256 1 opacity, Done. (0.027s)
# image 70/1263 /kaggle/covid19_test_images/0fedf74dc163.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 71/1263 /kaggle/covid19_test_images/100316af8a36.jpg: 224x256 1 opacity, Done. (0.028s)
# image 72/1263 /kaggle/covid19_test_images/1047ca1a704c.jpg: 224x256 Done. (0.027s)
# image 73/1263 /kaggle/covid19_test_images/1078af8ac3b7.jpg: 224x256 Done. (0.027s)
# image 74/1263 /kaggle/covid19_test_images/1093f305a358.jpg: 224x256 1 opacity, Done. (0.027s)
# image 75/1263 /kaggle/covid19_test_images/10d3c965a5b4.jpg: 224x256 Done. (0.027s)
# image 76/1263 /kaggle/covid19_test_images/11349660bb1a.jpg: 224x256 2 opacitys, Done. (0.031s)
# image 77/1263 /kaggle/covid19_test_images/1137ee93363f.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 78/1263 /kaggle/covid19_test_images/114f7f3baedf.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 79/1263 /kaggle/covid19_test_images/11541455ef19.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 80/1263 /kaggle/covid19_test_images/1177e1bef164.jpg: 224x256 1 opacity, Done. (0.027s)
# image 81/1263 /kaggle/covid19_test_images/1199fd9f2aba.jpg: 256x256 1 opacity, Done. (0.028s)
# image 82/1263 /kaggle/covid19_test_images/11abda231924.jpg: 224x256 1 opacity, Done. (0.028s)
# image 83/1263 /kaggle/covid19_test_images/11b60db4052a.jpg: 256x256 Done. (0.027s)
# image 84/1263 /kaggle/covid19_test_images/11b8e5179115.jpg: 256x256 1 opacity, Done. (0.027s)
# image 85/1263 /kaggle/covid19_test_images/11b9ab3af3db.jpg: 256x256 Done. (0.025s)
# image 86/1263 /kaggle/covid19_test_images/11d59a5488ed.jpg: 256x256 Done. (0.027s)
# image 87/1263 /kaggle/covid19_test_images/11dbf622932a.jpg: 256x224 Done. (0.028s)
# image 88/1263 /kaggle/covid19_test_images/11ef0d77a9c9.jpg: 224x256 Done. (0.028s)
# image 89/1263 /kaggle/covid19_test_images/11f8052288c7.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 90/1263 /kaggle/covid19_test_images/120ce3e7cd73.jpg: 224x256 Done. (0.027s)
# image 91/1263 /kaggle/covid19_test_images/127c2b32dd5d.jpg: 256x256 Done. (0.026s)
# image 92/1263 /kaggle/covid19_test_images/129846482a83.jpg: 256x256 Done. (0.026s)
# image 93/1263 /kaggle/covid19_test_images/12ae063a0dda.jpg: 256x256 1 opacity, Done. (0.027s)
# image 94/1263 /kaggle/covid19_test_images/12fbfd355d88.jpg: 224x256 Done. (0.026s)
# image 95/1263 /kaggle/covid19_test_images/1308d8906c2e.jpg: 224x256 Done. (0.027s)
# image 96/1263 /kaggle/covid19_test_images/130aa9d3716d.jpg: 224x256 1 opacity, Done. (0.027s)
# image 97/1263 /kaggle/covid19_test_images/1359178e428a.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 98/1263 /kaggle/covid19_test_images/13a28f6783b2.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 99/1263 /kaggle/covid19_test_images/13c550e44b7c.jpg: 224x256 Done. (0.026s)
# image 100/1263 /kaggle/covid19_test_images/144c27a2554a.jpg: 256x256 Done. (0.027s)
# image 101/1263 /kaggle/covid19_test_images/1450e124011a.jpg: 256x256 Done. (0.027s)
# image 102/1263 /kaggle/covid19_test_images/14658311d76e.jpg: 256x256 2 opacitys, Done. (0.027s)
# image 103/1263 /kaggle/covid19_test_images/14db2ff155f6.jpg: 224x256 Done. (0.035s)
# image 104/1263 /kaggle/covid19_test_images/14eb73431579.jpg: 224x256 Done. (0.026s)
# image 105/1263 /kaggle/covid19_test_images/14ec6bdb5641.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 106/1263 /kaggle/covid19_test_images/154b6a49ff75.jpg: 224x256 Done. (0.026s)
# image 107/1263 /kaggle/covid19_test_images/155f5e326d5e.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 108/1263 /kaggle/covid19_test_images/158cc858a485.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 109/1263 /kaggle/covid19_test_images/159cbf4e41e4.jpg: 224x256 Done. (0.041s)
# image 110/1263 /kaggle/covid19_test_images/160cfef3014f.jpg: 224x256 1 opacity, Done. (0.086s)
# image 111/1263 /kaggle/covid19_test_images/16237f3bc333.jpg: 224x256 2 opacitys, Done. (0.086s)
# image 112/1263 /kaggle/covid19_test_images/164dd63ae571.jpg: 224x256 2 opacitys, Done. (0.038s)
# image 113/1263 /kaggle/covid19_test_images/16972e92e827.jpg: 256x256 Done. (0.036s)
# image 114/1263 /kaggle/covid19_test_images/16a0d37747d7.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 115/1263 /kaggle/covid19_test_images/16d5b63ac279.jpg: 256x256 Done. (0.027s)
# image 116/1263 /kaggle/covid19_test_images/173c3e37e1f3.jpg: 256x256 Done. (0.026s)
# image 117/1263 /kaggle/covid19_test_images/179291642620.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 118/1263 /kaggle/covid19_test_images/17ac0fe388c7.jpg: 224x256 Done. (0.026s)
# image 119/1263 /kaggle/covid19_test_images/17d708d24ae8.jpg: 224x256 1 opacity, Done. (0.028s)
# image 120/1263 /kaggle/covid19_test_images/17e40efa4596.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 121/1263 /kaggle/covid19_test_images/180a5ea482c5.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 122/1263 /kaggle/covid19_test_images/181a2a300bb8.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 123/1263 /kaggle/covid19_test_images/1863b31637f6.jpg: 224x256 Done. (0.027s)
# image 124/1263 /kaggle/covid19_test_images/18a23df4fe99.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 125/1263 /kaggle/covid19_test_images/18e043b70fda.jpg: 224x256 Done. (0.027s)
# image 126/1263 /kaggle/covid19_test_images/18e6a4083920.jpg: 224x256 Done. (0.027s)
# image 127/1263 /kaggle/covid19_test_images/198ffac65dac.jpg: 224x256 Done. (0.027s)
# image 128/1263 /kaggle/covid19_test_images/19b0d2d65a38.jpg: 224x256 Done. (0.027s)
# image 129/1263 /kaggle/covid19_test_images/19e9733ee506.jpg: 224x256 Done. (0.026s)
# image 130/1263 /kaggle/covid19_test_images/1a1722362e19.jpg: 224x256 Done. (0.027s)
# image 131/1263 /kaggle/covid19_test_images/1a330ec81ee3.jpg: 224x256 1 opacity, Done. (0.027s)
# image 132/1263 /kaggle/covid19_test_images/1a4c378605f5.jpg: 224x256 Done. (0.027s)
# image 133/1263 /kaggle/covid19_test_images/1aa1491c9cd1.jpg: 224x256 Done. (0.027s)
# image 134/1263 /kaggle/covid19_test_images/1ab561ec5f7e.jpg: 224x256 1 opacity, Done. (0.028s)
# image 135/1263 /kaggle/covid19_test_images/1ade3b5d0699.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 136/1263 /kaggle/covid19_test_images/1aff7e4ed470.jpg: 224x256 1 opacity, Done. (0.028s)
# image 137/1263 /kaggle/covid19_test_images/1b0d0622ccea.jpg: 224x256 1 opacity, Done. (0.028s)
# image 138/1263 /kaggle/covid19_test_images/1b282faf0f42.jpg: 224x256 Done. (0.026s)
# image 139/1263 /kaggle/covid19_test_images/1b40a20045ee.jpg: 256x256 Done. (0.027s)
# image 140/1263 /kaggle/covid19_test_images/1b4cf5e0fbe0.jpg: 224x256 Done. (0.026s)
# image 141/1263 /kaggle/covid19_test_images/1b640a2839db.jpg: 224x256 1 opacity, Done. (0.027s)
# image 142/1263 /kaggle/covid19_test_images/1ba8aa7acf76.jpg: 224x256 1 opacity, Done. (0.028s)
# image 143/1263 /kaggle/covid19_test_images/1bc8687f938e.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 144/1263 /kaggle/covid19_test_images/1c13336fc8a9.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 145/1263 /kaggle/covid19_test_images/1c1c48cb66e4.jpg: 224x256 Done. (0.026s)
# image 146/1263 /kaggle/covid19_test_images/1c1e9d3f5bab.jpg: 256x256 Done. (0.027s)
# image 147/1263 /kaggle/covid19_test_images/1c47d2fcee72.jpg: 224x256 Done. (0.027s)
# image 148/1263 /kaggle/covid19_test_images/1c5aa8c405c7.jpg: 256x256 1 opacity, Done. (0.028s)
# image 149/1263 /kaggle/covid19_test_images/1c69c1af9a67.jpg: 256x256 Done. (0.026s)
# image 150/1263 /kaggle/covid19_test_images/1c8df7067e35.jpg: 256x256 1 opacity, Done. (0.028s)
# image 151/1263 /kaggle/covid19_test_images/1c937e2b91a9.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 152/1263 /kaggle/covid19_test_images/1c9c9f68941e.jpg: 224x256 1 opacity, Done. (0.028s)
# image 153/1263 /kaggle/covid19_test_images/1cbd87cb6bf9.jpg: 256x256 Done. (0.026s)
# image 154/1263 /kaggle/covid19_test_images/1ce9abb861b6.jpg: 224x256 Done. (0.026s)
# image 155/1263 /kaggle/covid19_test_images/1d674718db40.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 156/1263 /kaggle/covid19_test_images/1d981fb423e0.jpg: 224x256 Done. (0.027s)
# image 157/1263 /kaggle/covid19_test_images/1d9a8f9f0eef.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 158/1263 /kaggle/covid19_test_images/1dccbb75ffba.jpg: 256x256 Done. (0.028s)
# image 159/1263 /kaggle/covid19_test_images/1dfed0992998.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 160/1263 /kaggle/covid19_test_images/1e1734034b0f.jpg: 224x256 Done. (0.028s)
# image 161/1263 /kaggle/covid19_test_images/1e7429ce2e06.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 162/1263 /kaggle/covid19_test_images/1e9b7b493e47.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 163/1263 /kaggle/covid19_test_images/1eae0890a6ad.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 164/1263 /kaggle/covid19_test_images/1eb558739c44.jpg: 224x256 1 opacity, Done. (0.040s)
# image 165/1263 /kaggle/covid19_test_images/1ed201489300.jpg: 256x256 Done. (0.028s)
# image 166/1263 /kaggle/covid19_test_images/1f49246b305e.jpg: 224x256 Done. (0.028s)
# image 167/1263 /kaggle/covid19_test_images/1f737bcf6fe9.jpg: 256x256 1 opacity, Done. (0.029s)
# image 168/1263 /kaggle/covid19_test_images/1f927318863d.jpg: 224x256 Done. (0.028s)
# image 169/1263 /kaggle/covid19_test_images/1fb5ca50e8d3.jpg: 224x256 Done. (0.028s)
# image 170/1263 /kaggle/covid19_test_images/1fba9eccac03.jpg: 224x256 Done. (0.027s)
# image 171/1263 /kaggle/covid19_test_images/1fcfc9845e81.jpg: 256x256 Done. (0.028s)
# image 172/1263 /kaggle/covid19_test_images/1ff307ae0df6.jpg: 224x256 Done. (0.030s)
# image 173/1263 /kaggle/covid19_test_images/2083ae742497.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 174/1263 /kaggle/covid19_test_images/208c4c416450.jpg: 224x256 Done. (0.028s)
# image 175/1263 /kaggle/covid19_test_images/21ab319a926c.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 176/1263 /kaggle/covid19_test_images/21d1f013892c.jpg: 224x256 Done. (0.027s)
# image 177/1263 /kaggle/covid19_test_images/222601cefe1b.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 178/1263 /kaggle/covid19_test_images/223115cbf342.jpg: 256x224 Done. (0.028s)
# image 179/1263 /kaggle/covid19_test_images/2250e31a4999.jpg: 224x256 2 opacitys, Done. (0.036s)
# image 180/1263 /kaggle/covid19_test_images/236d240402cd.jpg: 224x256 2 opacitys, Done. (0.045s)
# image 181/1263 /kaggle/covid19_test_images/237aafc42d57.jpg: 224x256 Done. (0.037s)
# image 182/1263 /kaggle/covid19_test_images/23d8a619f39c.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 183/1263 /kaggle/covid19_test_images/23fd057dce2b.jpg: 256x256 1 opacity, Done. (0.028s)
# image 184/1263 /kaggle/covid19_test_images/240bf89e4d58.jpg: 224x256 Done. (0.029s)
# image 185/1263 /kaggle/covid19_test_images/2413a23a5477.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 186/1263 /kaggle/covid19_test_images/24ef59e133f6.jpg: 224x256 1 opacity, Done. (0.028s)
# image 187/1263 /kaggle/covid19_test_images/251f897c9e10.jpg: 256x256 1 opacity, Done. (0.029s)
# image 188/1263 /kaggle/covid19_test_images/252552312a42.jpg: 224x256 1 opacity, Done. (0.029s)
# image 189/1263 /kaggle/covid19_test_images/2533fc9ec975.jpg: 256x256 Done. (0.027s)
# image 190/1263 /kaggle/covid19_test_images/2565c5ccfba1.jpg: 224x256 1 opacity, Done. (0.031s)
# image 191/1263 /kaggle/covid19_test_images/256f0960de75.jpg: 256x256 Done. (0.028s)
# image 192/1263 /kaggle/covid19_test_images/25b281d5a9f3.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 193/1263 /kaggle/covid19_test_images/25d33047633c.jpg: 192x256 2 opacitys, Done. (0.037s)
# image 194/1263 /kaggle/covid19_test_images/25e11b9fb687.jpg: 224x256 Done. (0.028s)
# image 195/1263 /kaggle/covid19_test_images/26102c3f4f0f.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 196/1263 /kaggle/covid19_test_images/261b3d1adfe4.jpg: 256x256 1 opacity, Done. (0.030s)
# image 197/1263 /kaggle/covid19_test_images/262f3525e16a.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 198/1263 /kaggle/covid19_test_images/26454c05ce6e.jpg: 224x256 Done. (0.029s)
# image 199/1263 /kaggle/covid19_test_images/2663588e7048.jpg: 224x256 Done. (0.027s)
# image 200/1263 /kaggle/covid19_test_images/2686959fb3a5.jpg: 224x256 1 opacity, Done. (0.029s)
# image 201/1263 /kaggle/covid19_test_images/268d472480ec.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 202/1263 /kaggle/covid19_test_images/26da12104c4d.jpg: 224x256 Done. (0.026s)
# image 203/1263 /kaggle/covid19_test_images/26f2478e3e85.jpg: 256x256 Done. (0.026s)
# image 204/1263 /kaggle/covid19_test_images/26f55b8a7a94.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 205/1263 /kaggle/covid19_test_images/26fa9834387e.jpg: 224x256 1 opacity, Done. (0.027s)
# image 206/1263 /kaggle/covid19_test_images/271bea69026c.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 207/1263 /kaggle/covid19_test_images/2743e121b370.jpg: 224x256 Done. (0.027s)
# image 208/1263 /kaggle/covid19_test_images/275513358c80.jpg: 256x256 1 opacity, Done. (0.028s)
# image 209/1263 /kaggle/covid19_test_images/275c11b52bec.jpg: 224x256 Done. (0.028s)
# image 210/1263 /kaggle/covid19_test_images/27a4a0d2b7ec.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 211/1263 /kaggle/covid19_test_images/27d3da7a8e3d.jpg: 224x256 Done. (0.027s)
# image 212/1263 /kaggle/covid19_test_images/2857f0e19e09.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 213/1263 /kaggle/covid19_test_images/28b8c44feeb7.jpg: 224x256 Done. (0.027s)
# image 214/1263 /kaggle/covid19_test_images/28d0fa664e61.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 215/1263 /kaggle/covid19_test_images/290d07d7480f.jpg: 224x256 1 opacity, Done. (0.027s)
# image 216/1263 /kaggle/covid19_test_images/2910a7781437.jpg: 224x256 1 opacity, Done. (0.027s)
# image 217/1263 /kaggle/covid19_test_images/293014c67757.jpg: 224x256 Done. (0.026s)
# image 218/1263 /kaggle/covid19_test_images/2955c5ce3f0f.jpg: 224x256 Done. (0.027s)
# image 219/1263 /kaggle/covid19_test_images/29c992128fbd.jpg: 224x256 1 opacity, Done. (0.027s)
# image 220/1263 /kaggle/covid19_test_images/2a1dae5f6b5f.jpg: 224x256 Done. (0.026s)
# image 221/1263 /kaggle/covid19_test_images/2a2019322d8e.jpg: 224x256 Done. (0.025s)
# image 222/1263 /kaggle/covid19_test_images/2a2f54eb48df.jpg: 256x256 Done. (0.028s)
# image 223/1263 /kaggle/covid19_test_images/2a316bf62f59.jpg: 224x256 1 opacity, Done. (0.028s)
# image 224/1263 /kaggle/covid19_test_images/2a31b1526915.jpg: 256x256 Done. (0.028s)
# image 225/1263 /kaggle/covid19_test_images/2aaab6a41f1a.jpg: 224x256 1 opacity, Done. (0.028s)
# image 226/1263 /kaggle/covid19_test_images/2ae9c4c6566f.jpg: 224x256 1 opacity, Done. (0.028s)
# image 227/1263 /kaggle/covid19_test_images/2b59777ebc31.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 228/1263 /kaggle/covid19_test_images/2b7e9cf46376.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 229/1263 /kaggle/covid19_test_images/2b9cfe857b00.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 230/1263 /kaggle/covid19_test_images/2ba135370ac3.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 231/1263 /kaggle/covid19_test_images/2bc3736cc7bf.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 232/1263 /kaggle/covid19_test_images/2be1c227dbf2.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 233/1263 /kaggle/covid19_test_images/2be224a00fac.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 234/1263 /kaggle/covid19_test_images/2c1c4ab77d52.jpg: 224x256 1 opacity, Done. (0.027s)
# image 235/1263 /kaggle/covid19_test_images/2d58009c5ade.jpg: 256x256 Done. (0.027s)
# image 236/1263 /kaggle/covid19_test_images/2d6a4bc38540.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 237/1263 /kaggle/covid19_test_images/2dad900da56f.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 238/1263 /kaggle/covid19_test_images/2dbd5f171a0f.jpg: 224x256 Done. (0.026s)
# image 239/1263 /kaggle/covid19_test_images/2ddefbb957e9.jpg: 224x256 Done. (0.026s)
# image 240/1263 /kaggle/covid19_test_images/2de24d1c32bb.jpg: 256x256 Done. (0.027s)
# image 241/1263 /kaggle/covid19_test_images/2e131066f152.jpg: 256x256 Done. (0.026s)
# image 242/1263 /kaggle/covid19_test_images/2e4e44dfe103.jpg: 224x256 Done. (0.027s)
# image 243/1263 /kaggle/covid19_test_images/2f8c1d151802.jpg: 192x256 Done. (0.026s)
# image 244/1263 /kaggle/covid19_test_images/2f9ccb6faa68.jpg: 224x256 Done. (0.028s)
# image 245/1263 /kaggle/covid19_test_images/2fca6fe9c1ba.jpg: 224x256 Done. (0.027s)
# image 246/1263 /kaggle/covid19_test_images/2fd67e10bfe7.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 247/1263 /kaggle/covid19_test_images/303840f71bb5.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 248/1263 /kaggle/covid19_test_images/305870c916a4.jpg: 224x256 1 opacity, Done. (0.028s)
# image 249/1263 /kaggle/covid19_test_images/30b1c089724e.jpg: 224x256 1 opacity, Done. (0.027s)
# image 250/1263 /kaggle/covid19_test_images/317df13caea9.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 251/1263 /kaggle/covid19_test_images/318a1ecb6fc7.jpg: 256x256 Done. (0.044s)
# image 252/1263 /kaggle/covid19_test_images/31c07523a69a.jpg: 224x256 2 opacitys, Done. (0.039s)
# image 253/1263 /kaggle/covid19_test_images/3247432330d8.jpg: 224x256 Done. (0.028s)
# image 254/1263 /kaggle/covid19_test_images/3288907ddc51.jpg: 224x256 Done. (0.028s)
# image 255/1263 /kaggle/covid19_test_images/32b211904f5b.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 256/1263 /kaggle/covid19_test_images/32b23b347bb0.jpg: 224x256 Done. (0.026s)
# image 257/1263 /kaggle/covid19_test_images/32ecb7330e19.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 258/1263 /kaggle/covid19_test_images/33087aa9853d.jpg: 224x256 Done. (0.026s)
# image 259/1263 /kaggle/covid19_test_images/337662fe44ef.jpg: 224x256 Done. (0.026s)
# image 260/1263 /kaggle/covid19_test_images/33d456320f28.jpg: 224x256 Done. (0.026s)
# image 261/1263 /kaggle/covid19_test_images/33e0c978d0da.jpg: 224x256 1 opacity, Done. (0.028s)
# image 262/1263 /kaggle/covid19_test_images/340c9cf3b19a.jpg: 224x256 1 opacity, Done. (0.027s)
# image 263/1263 /kaggle/covid19_test_images/34270243e572.jpg: 256x256 Done. (0.028s)
# image 264/1263 /kaggle/covid19_test_images/34834851ec56.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 265/1263 /kaggle/covid19_test_images/349d5e5d8690.jpg: 224x256 Done. (0.027s)
# image 266/1263 /kaggle/covid19_test_images/34b713a5bb1d.jpg: 224x256 1 opacity, Done. (0.028s)
# image 267/1263 /kaggle/covid19_test_images/35271bec39b5.jpg: 224x256 1 opacity, Done. (0.027s)
# image 268/1263 /kaggle/covid19_test_images/3550632514dc.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 269/1263 /kaggle/covid19_test_images/35d6801ca10a.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 270/1263 /kaggle/covid19_test_images/35dd17ea3e6a.jpg: 224x256 1 opacity, Done. (0.027s)
# image 271/1263 /kaggle/covid19_test_images/3612ee150596.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 272/1263 /kaggle/covid19_test_images/36141cda67ad.jpg: 224x256 Done. (0.026s)
# image 273/1263 /kaggle/covid19_test_images/363dd47c8b10.jpg: 224x256 1 opacity, Done. (0.027s)
# image 274/1263 /kaggle/covid19_test_images/363fbf00088c.jpg: 224x256 Done. (0.027s)
# image 275/1263 /kaggle/covid19_test_images/36500eabad2d.jpg: 224x256 Done. (0.027s)
# image 276/1263 /kaggle/covid19_test_images/366e7eb393e5.jpg: 256x256 Done. (0.026s)
# image 277/1263 /kaggle/covid19_test_images/36a2991ffe0e.jpg: 256x256 Done. (0.026s)
# image 278/1263 /kaggle/covid19_test_images/36b323299f7e.jpg: 224x256 1 opacity, Done. (0.028s)
# image 279/1263 /kaggle/covid19_test_images/36ba388a18df.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 280/1263 /kaggle/covid19_test_images/36be4f943382.jpg: 224x256 Done. (0.026s)
# image 281/1263 /kaggle/covid19_test_images/36e1a455aafc.jpg: 256x256 Done. (0.027s)
# image 282/1263 /kaggle/covid19_test_images/37034ce54151.jpg: 224x256 1 opacity, Done. (0.029s)
# image 283/1263 /kaggle/covid19_test_images/3730eb76afba.jpg: 224x256 1 opacity, Done. (0.028s)
# image 284/1263 /kaggle/covid19_test_images/374e1b87d7b8.jpg: 256x224 2 opacitys, Done. (0.029s)
# image 285/1263 /kaggle/covid19_test_images/375b61c5cc94.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 286/1263 /kaggle/covid19_test_images/376d6d181b25.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 287/1263 /kaggle/covid19_test_images/37811132dc96.jpg: 224x256 Done. (0.027s)
# image 288/1263 /kaggle/covid19_test_images/37bf83df1b86.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 289/1263 /kaggle/covid19_test_images/37c6c0aee54b.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 290/1263 /kaggle/covid19_test_images/37cbf79c6de0.jpg: 224x256 Done. (0.027s)
# image 291/1263 /kaggle/covid19_test_images/37d6750b5282.jpg: 224x256 1 opacity, Done. (0.028s)
# image 292/1263 /kaggle/covid19_test_images/386343f0df08.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 293/1263 /kaggle/covid19_test_images/38b2e04ea601.jpg: 224x256 Done. (0.027s)
# image 294/1263 /kaggle/covid19_test_images/394892cb8a63.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 295/1263 /kaggle/covid19_test_images/39756fea8654.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 296/1263 /kaggle/covid19_test_images/39f8e38c9d43.jpg: 224x256 1 opacity, Done. (0.028s)
# image 297/1263 /kaggle/covid19_test_images/3a20fde98cdc.jpg: 224x256 Done. (0.027s)
# image 298/1263 /kaggle/covid19_test_images/3a2aa71a792e.jpg: 256x256 Done. (0.027s)
# image 299/1263 /kaggle/covid19_test_images/3a73591225ea.jpg: 224x256 Done. (0.027s)
# image 300/1263 /kaggle/covid19_test_images/3a81bc9c91c9.jpg: 224x256 Done. (0.026s)
# image 301/1263 /kaggle/covid19_test_images/3b1dcd10fa0e.jpg: 256x256 Done. (0.027s)
# image 302/1263 /kaggle/covid19_test_images/3b4ab121cbd4.jpg: 256x256 Done. (0.026s)
# image 303/1263 /kaggle/covid19_test_images/3b4e41cb8212.jpg: 224x256 Done. (0.028s)
# image 304/1263 /kaggle/covid19_test_images/3b5f48db44cc.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 305/1263 /kaggle/covid19_test_images/3b7ae6879147.jpg: 256x256 Done. (0.027s)
# image 306/1263 /kaggle/covid19_test_images/3b9fc021b611.jpg: 224x256 Done. (0.026s)
# image 307/1263 /kaggle/covid19_test_images/3bacdbd6ce10.jpg: 224x256 Done. (0.030s)
# image 308/1263 /kaggle/covid19_test_images/3bb8935d30d9.jpg: 224x256 Done. (0.026s)
# image 309/1263 /kaggle/covid19_test_images/3be5852db61e.jpg: 224x256 Done. (0.026s)
# image 310/1263 /kaggle/covid19_test_images/3bf0dc73f1fe.jpg: 256x256 Done. (0.028s)
# image 311/1263 /kaggle/covid19_test_images/3cccbd897c39.jpg: 256x256 Done. (0.027s)
# image 312/1263 /kaggle/covid19_test_images/3d465a00a9b6.jpg: 224x256 1 opacity, Done. (0.032s)
# image 313/1263 /kaggle/covid19_test_images/3d47cc325262.jpg: 256x256 Done. (0.027s)
# image 314/1263 /kaggle/covid19_test_images/3d4fb4320278.jpg: 256x256 Done. (0.026s)
# image 315/1263 /kaggle/covid19_test_images/3d56a237b6be.jpg: 224x256 Done. (0.040s)
# image 316/1263 /kaggle/covid19_test_images/3d623665afd7.jpg: 256x256 Done. (0.039s)
# image 317/1263 /kaggle/covid19_test_images/3d639e7999a5.jpg: 224x256 2 opacitys, Done. (0.041s)
# image 318/1263 /kaggle/covid19_test_images/3dcdfc352a06.jpg: 224x256 Done. (0.076s)
# image 319/1263 /kaggle/covid19_test_images/3dfa8d9f66f4.jpg: 256x256 Done. (0.066s)
# image 320/1263 /kaggle/covid19_test_images/3e4b4468eca3.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 321/1263 /kaggle/covid19_test_images/3ed35204df56.jpg: 256x256 Done. (0.027s)
# image 322/1263 /kaggle/covid19_test_images/3f133fac447c.jpg: 224x256 Done. (0.026s)
# image 323/1263 /kaggle/covid19_test_images/3f1439b85338.jpg: 224x256 1 opacity, Done. (0.027s)
# image 324/1263 /kaggle/covid19_test_images/3f8195c5362d.jpg: 224x256 Done. (0.025s)
# image 325/1263 /kaggle/covid19_test_images/3fe73d3b28b9.jpg: 224x256 Done. (0.026s)
# image 326/1263 /kaggle/covid19_test_images/4040afec3ee4.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 327/1263 /kaggle/covid19_test_images/4041be34745f.jpg: 224x256 Done. (0.027s)
# image 328/1263 /kaggle/covid19_test_images/404d53460643.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 329/1263 /kaggle/covid19_test_images/405d774f17d5.jpg: 256x256 Done. (0.027s)
# image 330/1263 /kaggle/covid19_test_images/409322480a9b.jpg: 224x256 1 opacity, Done. (0.029s)
# image 331/1263 /kaggle/covid19_test_images/41251dd79bb3.jpg: 256x256 1 opacity, Done. (0.028s)
# image 332/1263 /kaggle/covid19_test_images/413344e1032c.jpg: 224x256 1 opacity, Done. (0.029s)
# image 333/1263 /kaggle/covid19_test_images/41c25ec8c44c.jpg: 256x256 Done. (0.028s)
# image 334/1263 /kaggle/covid19_test_images/41c26ea10186.jpg: 256x256 Done. (0.026s)
# image 335/1263 /kaggle/covid19_test_images/422c0e145066.jpg: 256x256 Done. (0.026s)
# image 336/1263 /kaggle/covid19_test_images/435bc0fcb0ab.jpg: 256x256 Done. (0.028s)
# image 337/1263 /kaggle/covid19_test_images/43e370c03cd2.jpg: 224x256 1 opacity, Done. (0.028s)
# image 338/1263 /kaggle/covid19_test_images/440de3bfe05a.jpg: 256x256 Done. (0.026s)
# image 339/1263 /kaggle/covid19_test_images/445298de90b9.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 340/1263 /kaggle/covid19_test_images/44b12000b7bf.jpg: 224x256 Done. (0.027s)
# image 341/1263 /kaggle/covid19_test_images/458417ad6155.jpg: 224x256 1 opacity, Done. (0.027s)
# image 342/1263 /kaggle/covid19_test_images/45a57e934e94.jpg: 256x256 Done. (0.027s)
# image 343/1263 /kaggle/covid19_test_images/45bc12129df2.jpg: 256x256 Done. (0.027s)
# image 344/1263 /kaggle/covid19_test_images/46719b856de1.jpg: 256x256 Done. (0.026s)
# image 345/1263 /kaggle/covid19_test_images/471f3f81a718.jpg: 256x256 Done. (0.027s)
# image 346/1263 /kaggle/covid19_test_images/476dec5c36e1.jpg: 224x256 1 opacity, Done. (0.028s)
# image 347/1263 /kaggle/covid19_test_images/47a976677416.jpg: 224x256 1 opacity, Done. (0.030s)
# image 348/1263 /kaggle/covid19_test_images/47ea205fd755.jpg: 224x256 Done. (0.027s)
# image 349/1263 /kaggle/covid19_test_images/4810ae5dbc08.jpg: 224x256 1 opacity, Done. (0.028s)
# image 350/1263 /kaggle/covid19_test_images/4855b78e0df2.jpg: 224x256 Done. (0.026s)
# image 351/1263 /kaggle/covid19_test_images/4905b651a091.jpg: 256x256 Done. (0.026s)
# image 352/1263 /kaggle/covid19_test_images/49c1b06028a1.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 353/1263 /kaggle/covid19_test_images/49e9379c42dc.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 354/1263 /kaggle/covid19_test_images/49fb3141efe3.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 355/1263 /kaggle/covid19_test_images/4acbd31eafd5.jpg: 224x256 Done. (0.026s)
# image 356/1263 /kaggle/covid19_test_images/4b0058c1f54e.jpg: 224x256 1 opacity, Done. (0.028s)
# image 357/1263 /kaggle/covid19_test_images/4bf0dc7bae40.jpg: 224x256 Done. (0.026s)
# image 358/1263 /kaggle/covid19_test_images/4c0658c05a64.jpg: 256x256 Done. (0.027s)
# image 359/1263 /kaggle/covid19_test_images/4c2d931d0f33.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 360/1263 /kaggle/covid19_test_images/4c3ca06916a1.jpg: 224x256 Done. (0.027s)
# image 361/1263 /kaggle/covid19_test_images/4c3dbddfc294.jpg: 256x256 Done. (0.026s)
# image 362/1263 /kaggle/covid19_test_images/4c4737c3e3f8.jpg: 256x256 Done. (0.026s)
# image 363/1263 /kaggle/covid19_test_images/4c56fe85fa4f.jpg: 224x256 Done. (0.027s)
# image 364/1263 /kaggle/covid19_test_images/4ccb8a39c77a.jpg: 256x256 1 opacity, Done. (0.030s)
# image 365/1263 /kaggle/covid19_test_images/4d105a99d866.jpg: 256x256 Done. (0.026s)
# image 366/1263 /kaggle/covid19_test_images/4d1bf3193a0c.jpg: 224x256 Done. (0.027s)
# image 367/1263 /kaggle/covid19_test_images/4d56b2fc668c.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 368/1263 /kaggle/covid19_test_images/4d6c8e93e7c9.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 369/1263 /kaggle/covid19_test_images/4d7b06512cc1.jpg: 224x256 1 opacity, Done. (0.027s)
# image 370/1263 /kaggle/covid19_test_images/4e01dd0a5fdf.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 371/1263 /kaggle/covid19_test_images/4e126f476f86.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 372/1263 /kaggle/covid19_test_images/4ea555b6e2a8.jpg: 224x256 Done. (0.027s)
# image 373/1263 /kaggle/covid19_test_images/4eb36901f082.jpg: 224x256 1 opacity, Done. (0.027s)
# image 374/1263 /kaggle/covid19_test_images/4eb9a8ab1559.jpg: 256x256 Done. (0.027s)
# image 375/1263 /kaggle/covid19_test_images/4ece84b1cfb8.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 376/1263 /kaggle/covid19_test_images/4eceeddd00ca.jpg: 224x256 1 opacity, Done. (0.028s)
# image 377/1263 /kaggle/covid19_test_images/4eecfe2a4de1.jpg: 224x256 Done. (0.027s)
# image 378/1263 /kaggle/covid19_test_images/4f1ad3374103.jpg: 224x256 Done. (0.027s)
# image 379/1263 /kaggle/covid19_test_images/4f7f40e478b1.jpg: 256x256 1 opacity, Done. (0.028s)
# image 380/1263 /kaggle/covid19_test_images/4f83ec489a15.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 381/1263 /kaggle/covid19_test_images/4fc12ae446a8.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 382/1263 /kaggle/covid19_test_images/4fe0444d7fc5.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 383/1263 /kaggle/covid19_test_images/4fe79f658041.jpg: 224x256 Done. (0.025s)
# image 384/1263 /kaggle/covid19_test_images/4ffdca4189d5.jpg: 224x256 Done. (0.026s)
# image 385/1263 /kaggle/covid19_test_images/4fff9ae1ff37.jpg: 256x256 Done. (0.026s)
# image 386/1263 /kaggle/covid19_test_images/50201fe80b1b.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 387/1263 /kaggle/covid19_test_images/5020cd97beb8.jpg: 224x256 2 opacitys, Done. (0.042s)
# image 388/1263 /kaggle/covid19_test_images/50243b2cdb56.jpg: 224x256 Done. (0.038s)
# image 389/1263 /kaggle/covid19_test_images/503a6e0884c6.jpg: 256x256 Done. (0.037s)
# image 390/1263 /kaggle/covid19_test_images/50537bcf4cc2.jpg: 224x256 1 opacity, Done. (0.029s)
# image 391/1263 /kaggle/covid19_test_images/5058f3b157e3.jpg: 224x256 Done. (0.026s)
# image 392/1263 /kaggle/covid19_test_images/509c535a3dc1.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 393/1263 /kaggle/covid19_test_images/50c0e40fd929.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 394/1263 /kaggle/covid19_test_images/50de91c4297d.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 395/1263 /kaggle/covid19_test_images/50dfcc0c2826.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 396/1263 /kaggle/covid19_test_images/51635cbfbe18.jpg: 224x256 1 opacity, Done. (0.030s)
# image 397/1263 /kaggle/covid19_test_images/5163e54f5fc1.jpg: 224x256 Done. (0.028s)
# image 398/1263 /kaggle/covid19_test_images/516d9b3ee48c.jpg: 224x256 1 opacity, Done. (0.027s)
# image 399/1263 /kaggle/covid19_test_images/516e4adba012.jpg: 224x256 Done. (0.026s)
# image 400/1263 /kaggle/covid19_test_images/5175b9a4a25e.jpg: 224x256 1 opacity, Done. (0.027s)
# image 401/1263 /kaggle/covid19_test_images/51a0100c5921.jpg: 224x256 Done. (0.028s)
# image 402/1263 /kaggle/covid19_test_images/51aedbecbf46.jpg: 256x256 Done. (0.026s)
# image 403/1263 /kaggle/covid19_test_images/51cbf7662bee.jpg: 224x256 Done. (0.026s)
# image 404/1263 /kaggle/covid19_test_images/51d2f37f3f60.jpg: 224x256 Done. (0.027s)
# image 405/1263 /kaggle/covid19_test_images/51d9dda5e493.jpg: 224x256 Done. (0.026s)
# image 406/1263 /kaggle/covid19_test_images/51ea4e1227bd.jpg: 256x256 1 opacity, Done. (0.028s)
# image 407/1263 /kaggle/covid19_test_images/520a1a7b039b.jpg: 224x256 Done. (0.026s)
# image 408/1263 /kaggle/covid19_test_images/52168ec4f7c5.jpg: 224x256 Done. (0.026s)
# image 409/1263 /kaggle/covid19_test_images/5232ab4c4671.jpg: 224x256 Done. (0.025s)
# image 410/1263 /kaggle/covid19_test_images/52f02af216bb.jpg: 224x256 Done. (0.027s)
# image 411/1263 /kaggle/covid19_test_images/53316aefede6.jpg: 256x256 1 opacity, Done. (0.028s)
# image 412/1263 /kaggle/covid19_test_images/536da2d8df21.jpg: 224x256 Done. (0.026s)
# image 413/1263 /kaggle/covid19_test_images/5378fb58d2d1.jpg: 224x256 1 opacity, Done. (0.027s)
# image 414/1263 /kaggle/covid19_test_images/539931eced05.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 415/1263 /kaggle/covid19_test_images/53b0dc275cb0.jpg: 224x256 1 opacity, Done. (0.026s)
# image 416/1263 /kaggle/covid19_test_images/53b4af5b74d7.jpg: 256x256 Done. (0.027s)
# image 417/1263 /kaggle/covid19_test_images/53c971120ab1.jpg: 224x256 1 opacity, Done. (0.029s)
# image 418/1263 /kaggle/covid19_test_images/54066d711ef9.jpg: 224x256 Done. (0.026s)
# image 419/1263 /kaggle/covid19_test_images/5472531dd991.jpg: 256x256 Done. (0.027s)
# image 420/1263 /kaggle/covid19_test_images/550a6a9ee91e.jpg: 224x256 Done. (0.027s)
# image 421/1263 /kaggle/covid19_test_images/551957feafcc.jpg: 224x256 Done. (0.027s)
# image 422/1263 /kaggle/covid19_test_images/553cc2a7b556.jpg: 224x256 Done. (0.026s)
# image 423/1263 /kaggle/covid19_test_images/55433651ec05.jpg: 224x256 Done. (0.026s)
# image 424/1263 /kaggle/covid19_test_images/557a70442928.jpg: 256x256 Done. (0.027s)
# image 425/1263 /kaggle/covid19_test_images/5592c8778ae2.jpg: 224x256 Done. (0.027s)
# image 426/1263 /kaggle/covid19_test_images/5596c4063d58.jpg: 256x256 Done. (0.026s)
# image 427/1263 /kaggle/covid19_test_images/55ea6ce07bdd.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 428/1263 /kaggle/covid19_test_images/55ecad406759.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 429/1263 /kaggle/covid19_test_images/55f69f03ee2f.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 430/1263 /kaggle/covid19_test_images/56414fb3f177.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 431/1263 /kaggle/covid19_test_images/5699fc89704f.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 432/1263 /kaggle/covid19_test_images/56a3fb6663bf.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 433/1263 /kaggle/covid19_test_images/56b010725833.jpg: 224x256 Done. (0.028s)
# image 434/1263 /kaggle/covid19_test_images/572d5c14fc66.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 435/1263 /kaggle/covid19_test_images/574b38d8f6ee.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 436/1263 /kaggle/covid19_test_images/5765f6b4707d.jpg: 224x256 1 opacity, Done. (0.026s)
# image 437/1263 /kaggle/covid19_test_images/576cbe3e3680.jpg: 224x256 Done. (0.026s)
# image 438/1263 /kaggle/covid19_test_images/57879f49e8a7.jpg: 256x256 Done. (0.027s)
# image 439/1263 /kaggle/covid19_test_images/57d169dabba7.jpg: 256x256 Done. (0.027s)
# image 440/1263 /kaggle/covid19_test_images/586b00a19a17.jpg: 224x256 Done. (0.027s)
# image 441/1263 /kaggle/covid19_test_images/5878b290f09a.jpg: 224x256 1 opacity, Done. (0.027s)
# image 442/1263 /kaggle/covid19_test_images/58bc298e0f9f.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 443/1263 /kaggle/covid19_test_images/59911e31f963.jpg: 224x256 1 opacity, Done. (0.027s)
# image 444/1263 /kaggle/covid19_test_images/59a0fc64bd20.jpg: 256x256 1 opacity, Done. (0.028s)
# image 445/1263 /kaggle/covid19_test_images/59c4bfbf8b5b.jpg: 224x256 Done. (0.026s)
# image 446/1263 /kaggle/covid19_test_images/59d238641bee.jpg: 256x256 Done. (0.027s)
# image 447/1263 /kaggle/covid19_test_images/5a0de0207028.jpg: 224x256 Done. (0.027s)
# image 448/1263 /kaggle/covid19_test_images/5a2b8c736aa3.jpg: 256x256 Done. (0.027s)
# image 449/1263 /kaggle/covid19_test_images/5a73ab51749e.jpg: 224x256 Done. (0.027s)
# image 450/1263 /kaggle/covid19_test_images/5aa20bb0feb2.jpg: 224x256 Done. (0.026s)
# image 451/1263 /kaggle/covid19_test_images/5ac874337f82.jpg: 224x256 Done. (0.025s)
# image 452/1263 /kaggle/covid19_test_images/5adf919e765a.jpg: 224x256 Done. (0.027s)
# image 453/1263 /kaggle/covid19_test_images/5af15b21333b.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 454/1263 /kaggle/covid19_test_images/5b12f6b2c93e.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 455/1263 /kaggle/covid19_test_images/5b27050cfb90.jpg: 224x256 Done. (0.026s)
# image 456/1263 /kaggle/covid19_test_images/5b75a1de503b.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 457/1263 /kaggle/covid19_test_images/5b8ee5baa1d5.jpg: 224x256 Done. (0.027s)
# image 458/1263 /kaggle/covid19_test_images/5ba33931fc64.jpg: 224x256 Done. (0.026s)
# image 459/1263 /kaggle/covid19_test_images/5bab1b955f2a.jpg: 256x256 Done. (0.027s)
# image 460/1263 /kaggle/covid19_test_images/5badf765648c.jpg: 256x256 Done. (0.026s)
# image 461/1263 /kaggle/covid19_test_images/5c4c752c1e46.jpg: 256x256 Done. (0.041s)
# image 462/1263 /kaggle/covid19_test_images/5c88a5fc55e7.jpg: 224x256 2 opacitys, Done. (0.040s)
# image 463/1263 /kaggle/covid19_test_images/5c8c441a0650.jpg: 256x256 Done. (0.037s)
# image 464/1263 /kaggle/covid19_test_images/5c90beaa5c48.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 465/1263 /kaggle/covid19_test_images/5c9f41283e7c.jpg: 224x256 Done. (0.026s)
# image 466/1263 /kaggle/covid19_test_images/5cb984539107.jpg: 224x256 1 opacity, Done. (0.028s)
# image 467/1263 /kaggle/covid19_test_images/5db9599cf9f7.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 468/1263 /kaggle/covid19_test_images/5dba2b3647b1.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 469/1263 /kaggle/covid19_test_images/5dd9e477a6ee.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 470/1263 /kaggle/covid19_test_images/5dfad16f8d65.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 471/1263 /kaggle/covid19_test_images/5e0e7acd9c7d.jpg: 224x256 Done. (0.026s)
# image 472/1263 /kaggle/covid19_test_images/5e64da034f7a.jpg: 224x256 1 opacity, Done. (0.027s)
# image 473/1263 /kaggle/covid19_test_images/5e8ac1fe2b82.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 474/1263 /kaggle/covid19_test_images/5e8d99b9ab38.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 475/1263 /kaggle/covid19_test_images/5eb97e03c468.jpg: 224x256 1 opacity, Done. (0.027s)
# image 476/1263 /kaggle/covid19_test_images/5ee582e2463a.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 477/1263 /kaggle/covid19_test_images/5f65421ff6fd.jpg: 256x256 Done. (0.027s)
# image 478/1263 /kaggle/covid19_test_images/5fa584b8b4ad.jpg: 224x256 1 opacity, Done. (0.028s)
# image 479/1263 /kaggle/covid19_test_images/5fba37ac7937.jpg: 256x256 2 opacitys, Done. (0.029s)
# image 480/1263 /kaggle/covid19_test_images/5fbc3a77d700.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 481/1263 /kaggle/covid19_test_images/5fbec0b4056c.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 482/1263 /kaggle/covid19_test_images/60197b6237e4.jpg: 224x256 Done. (0.027s)
# image 483/1263 /kaggle/covid19_test_images/603addd70746.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 484/1263 /kaggle/covid19_test_images/604bd55c21c6.jpg: 224x256 3 opacitys, Done. (0.028s)
# image 485/1263 /kaggle/covid19_test_images/609361f18122.jpg: 256x256 1 opacity, Done. (0.028s)
# image 486/1263 /kaggle/covid19_test_images/60f94703051a.jpg: 224x256 Done. (0.029s)
# image 487/1263 /kaggle/covid19_test_images/61505043bc32.jpg: 224x256 Done. (0.027s)
# image 488/1263 /kaggle/covid19_test_images/61884a13a399.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 489/1263 /kaggle/covid19_test_images/620191dbdfa4.jpg: 224x256 Done. (0.027s)
# image 490/1263 /kaggle/covid19_test_images/629ef3bd6a66.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 491/1263 /kaggle/covid19_test_images/62eca401e981.jpg: 224x256 Done. (0.027s)
# image 492/1263 /kaggle/covid19_test_images/62fb484194fb.jpg: 224x256 1 opacity, Done. (0.027s)
# image 493/1263 /kaggle/covid19_test_images/63173909bed5.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 494/1263 /kaggle/covid19_test_images/633e41912f6e.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 495/1263 /kaggle/covid19_test_images/639f6bf3c727.jpg: 224x256 Done. (0.026s)
# image 496/1263 /kaggle/covid19_test_images/649b529933d6.jpg: 224x256 1 opacity, Done. (0.027s)
# image 497/1263 /kaggle/covid19_test_images/64c64a317c96.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 498/1263 /kaggle/covid19_test_images/64ea82b1343f.jpg: 224x256 1 opacity, Done. (0.027s)
# image 499/1263 /kaggle/covid19_test_images/65045f5ef280.jpg: 224x256 Done. (0.025s)
# image 500/1263 /kaggle/covid19_test_images/65a02e95292e.jpg: 224x256 Done. (0.026s)
# image 501/1263 /kaggle/covid19_test_images/65a5d46ef968.jpg: 224x256 Done. (0.040s)
# image 502/1263 /kaggle/covid19_test_images/65acc1fb99a3.jpg: 256x256 Done. (0.041s)
# image 503/1263 /kaggle/covid19_test_images/65be7fc2448a.jpg: 224x256 1 opacity, Done. (0.028s)
# image 504/1263 /kaggle/covid19_test_images/6610e4632963.jpg: 224x256 Done. (0.028s)
# image 505/1263 /kaggle/covid19_test_images/661343e25b55.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 506/1263 /kaggle/covid19_test_images/664250f0f623.jpg: 224x256 Done. (0.026s)
# image 507/1263 /kaggle/covid19_test_images/66ca7bb52ab9.jpg: 224x256 Done. (0.026s)
# image 508/1263 /kaggle/covid19_test_images/66d812201e73.jpg: 224x256 Done. (0.026s)
# image 509/1263 /kaggle/covid19_test_images/6707b082f3c9.jpg: 224x256 Done. (0.028s)
# image 510/1263 /kaggle/covid19_test_images/670989e56968.jpg: 224x256 1 opacity, Done. (0.027s)
# image 511/1263 /kaggle/covid19_test_images/6746a1932779.jpg: 224x256 Done. (0.029s)
# image 512/1263 /kaggle/covid19_test_images/6758e5ed7742.jpg: 224x256 1 opacity, Done. (0.027s)
# image 513/1263 /kaggle/covid19_test_images/67f192ad1a53.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 514/1263 /kaggle/covid19_test_images/681766974456.jpg: 224x256 Done. (0.025s)
# image 515/1263 /kaggle/covid19_test_images/6828795ea830.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 516/1263 /kaggle/covid19_test_images/68b95eed58ed.jpg: 256x256 Done. (0.027s)
# image 517/1263 /kaggle/covid19_test_images/695e2c6dede4.jpg: 224x256 Done. (0.027s)
# image 518/1263 /kaggle/covid19_test_images/697a674d44e0.jpg: 256x224 2 opacitys, Done. (0.030s)
# image 519/1263 /kaggle/covid19_test_images/699fc1ec26f9.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 520/1263 /kaggle/covid19_test_images/69ace2980660.jpg: 224x256 Done. (0.026s)
# image 521/1263 /kaggle/covid19_test_images/69d1134dccc6.jpg: 256x256 Done. (0.027s)
# image 522/1263 /kaggle/covid19_test_images/69ffab5539ec.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 523/1263 /kaggle/covid19_test_images/6a0889223a38.jpg: 256x256 Done. (0.027s)
# image 524/1263 /kaggle/covid19_test_images/6a5a6eaef699.jpg: 224x256 1 opacity, Done. (0.028s)
# image 525/1263 /kaggle/covid19_test_images/6a99f80ffa1b.jpg: 256x256 1 opacity, Done. (0.043s)
# image 526/1263 /kaggle/covid19_test_images/6aedc81fb62d.jpg: 224x256 Done. (0.039s)
# image 527/1263 /kaggle/covid19_test_images/6af96c8a94c9.jpg: 256x256 Done. (0.039s)
# image 528/1263 /kaggle/covid19_test_images/6b07294c7674.jpg: 224x256 1 opacity, Done. (0.039s)
# image 529/1263 /kaggle/covid19_test_images/6bce1f945580.jpg: 256x256 1 opacity, Done. (0.039s)
# image 530/1263 /kaggle/covid19_test_images/6be23f5c40f3.jpg: 224x256 Done. (0.055s)
# ...
# image 1090/1263 /kaggle/covid19_test_images/dba0caa176ce.jpg: 256x224 Done. (0.026s)
# image 1091/1263 /kaggle/covid19_test_images/dbae9b9b9500.jpg: 224x256 Done. (0.030s)
# image 1092/1263 /kaggle/covid19_test_images/dc0b4b3495c4.jpg: 224x256 1 opacity, Done. (0.030s)
# image 1093/1263 /kaggle/covid19_test_images/dc5141a2316a.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1094/1263 /kaggle/covid19_test_images/dc58aecf62e3.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1095/1263 /kaggle/covid19_test_images/dc6834a1efa6.jpg: 256x256 Done. (0.027s)
# image 1096/1263 /kaggle/covid19_test_images/dcf6740dbc49.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1097/1263 /kaggle/covid19_test_images/ddd7ad8b0c41.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1098/1263 /kaggle/covid19_test_images/dded54f9de15.jpg: 256x256 Done. (0.027s)
# image 1099/1263 /kaggle/covid19_test_images/de0cf08fcad0.jpg: 224x256 Done. (0.041s)
# image 1100/1263 /kaggle/covid19_test_images/de1b8900bf84.jpg: 224x256 1 opacity, Done. (0.041s)
# image 1101/1263 /kaggle/covid19_test_images/de56c2d5b778.jpg: 256x256 Done. (0.041s)
# image 1102/1263 /kaggle/covid19_test_images/dea7079400f8.jpg: 256x256 Done. (0.040s)
# image 1103/1263 /kaggle/covid19_test_images/deb2db0a0efb.jpg: 224x256 Done. (0.027s)
# image 1104/1263 /kaggle/covid19_test_images/dee71f5c5b9c.jpg: 256x256 3 opacitys, Done. (0.029s)
# image 1105/1263 /kaggle/covid19_test_images/df829b7602ce.jpg: 256x256 Done. (0.027s)
# image 1106/1263 /kaggle/covid19_test_images/df937504e546.jpg: 256x256 Done. (0.047s)
# image 1107/1263 /kaggle/covid19_test_images/dfb6a487e854.jpg: 224x256 2 opacitys, Done. (0.040s)
# image 1108/1263 /kaggle/covid19_test_images/dfc5c09a50bc.jpg: 224x256 Done. (0.038s)
# image 1109/1263 /kaggle/covid19_test_images/e002731bb6cb.jpg: 224x256 Done. (0.027s)
# image 1110/1263 /kaggle/covid19_test_images/e00b7784d1eb.jpg: 256x256 Done. (0.027s)
# image 1111/1263 /kaggle/covid19_test_images/e036a057d0cf.jpg: 224x256 Done. (0.027s)
# image 1112/1263 /kaggle/covid19_test_images/e0daaf8d36a4.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1113/1263 /kaggle/covid19_test_images/e134e2ffdfaf.jpg: 224x256 Done. (0.027s)
# image 1114/1263 /kaggle/covid19_test_images/e150241b43a4.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1115/1263 /kaggle/covid19_test_images/e1635f289c95.jpg: 256x256 Done. (0.028s)
# image 1116/1263 /kaggle/covid19_test_images/e19d8286b13b.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1117/1263 /kaggle/covid19_test_images/e20cf732e8eb.jpg: 256x256 Done. (0.027s)
# image 1118/1263 /kaggle/covid19_test_images/e226747a2d76.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 1119/1263 /kaggle/covid19_test_images/e23027c8bea6.jpg: 256x256 1 opacity, Done. (0.029s)
# image 1120/1263 /kaggle/covid19_test_images/e252ffbf487e.jpg: 224x256 Done. (0.027s)
# image 1121/1263 /kaggle/covid19_test_images/e2c038335c9a.jpg: 256x256 1 opacity, Done. (0.029s)
# image 1122/1263 /kaggle/covid19_test_images/e2f83c4e9c79.jpg: 224x256 1 opacity, Done. (0.026s)
# image 1123/1263 /kaggle/covid19_test_images/e3179eb2ff82.jpg: 224x256 Done. (0.025s)
# image 1124/1263 /kaggle/covid19_test_images/e32589cd4421.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1125/1263 /kaggle/covid19_test_images/e3a4dddc69b6.jpg: 256x256 Done. (0.026s)
# image 1126/1263 /kaggle/covid19_test_images/e3cd1fdf2444.jpg: 224x256 Done. (0.027s)
# image 1127/1263 /kaggle/covid19_test_images/e3eeddbfba24.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1128/1263 /kaggle/covid19_test_images/e420d66bb7f8.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1129/1263 /kaggle/covid19_test_images/e427d54f3926.jpg: 224x256 Done. (0.026s)
# image 1130/1263 /kaggle/covid19_test_images/e47df1ad9ccf.jpg: 224x256 Done. (0.026s)
# image 1131/1263 /kaggle/covid19_test_images/e49489fcf5c0.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1132/1263 /kaggle/covid19_test_images/e53c7af3541a.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1133/1263 /kaggle/covid19_test_images/e59126042b0e.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1134/1263 /kaggle/covid19_test_images/e5a860104190.jpg: 224x256 Done. (0.026s)
# image 1135/1263 /kaggle/covid19_test_images/e5c56ef2d194.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 1136/1263 /kaggle/covid19_test_images/e5e44940be7a.jpg: 256x256 Done. (0.029s)
# image 1137/1263 /kaggle/covid19_test_images/e5f1d33714e6.jpg: 224x256 2 opacitys, Done. (0.032s)
# image 1138/1263 /kaggle/covid19_test_images/e61e420938b6.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1139/1263 /kaggle/covid19_test_images/e71a18669122.jpg: 224x256 Done. (0.026s)
# image 1140/1263 /kaggle/covid19_test_images/e730aa7fca0a.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1141/1263 /kaggle/covid19_test_images/e78f51cdf0b8.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1142/1263 /kaggle/covid19_test_images/e7b2a9418b98.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 1143/1263 /kaggle/covid19_test_images/e831bebfa015.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1144/1263 /kaggle/covid19_test_images/e85bb0bcca1f.jpg: 256x256 Done. (0.027s)
# image 1145/1263 /kaggle/covid19_test_images/e88f293bc83a.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1146/1263 /kaggle/covid19_test_images/e8b4525ec41f.jpg: 224x256 Done. (0.027s)
# image 1147/1263 /kaggle/covid19_test_images/e8cc6a2f117c.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1148/1263 /kaggle/covid19_test_images/e8d690e0d67d.jpg: 224x256 Done. (0.025s)
# image 1149/1263 /kaggle/covid19_test_images/e8d801584d89.jpg: 224x256 1 opacity, Done. (0.029s)
# image 1150/1263 /kaggle/covid19_test_images/e92b08b5a77c.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1151/1263 /kaggle/covid19_test_images/e95803934fc4.jpg: 256x256 Done. (0.027s)
# image 1152/1263 /kaggle/covid19_test_images/e9783e91ed84.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1153/1263 /kaggle/covid19_test_images/e987cb5ca98b.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1154/1263 /kaggle/covid19_test_images/e9a3b9253cd3.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1155/1263 /kaggle/covid19_test_images/ea1c164158da.jpg: 256x256 Done. (0.026s)
# image 1156/1263 /kaggle/covid19_test_images/ea39ebfacca2.jpg: 256x256 Done. (0.026s)
# image 1157/1263 /kaggle/covid19_test_images/ea5341f767eb.jpg: 256x256 Done. (0.026s)
# image 1158/1263 /kaggle/covid19_test_images/ea71a8b95d30.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 1159/1263 /kaggle/covid19_test_images/ea7909e782fe.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1160/1263 /kaggle/covid19_test_images/ea79274e2bfd.jpg: 256x256 Done. (0.026s)
# image 1161/1263 /kaggle/covid19_test_images/ea9ee4d59c59.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1162/1263 /kaggle/covid19_test_images/eaa1d528538f.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1163/1263 /kaggle/covid19_test_images/eaad41dd9fe3.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1164/1263 /kaggle/covid19_test_images/eaec01e48714.jpg: 224x256 2 opacitys, Done. (0.038s)
# image 1165/1263 /kaggle/covid19_test_images/eb3fe9eb8e39.jpg: 224x256 1 opacity, Done. (0.043s)
# image 1166/1263 /kaggle/covid19_test_images/eb4d5d8af5a5.jpg: 256x256 Done. (0.043s)
# image 1167/1263 /kaggle/covid19_test_images/eb5787b68520.jpg: 224x256 Done. (0.037s)
# image 1168/1263 /kaggle/covid19_test_images/eb632adfa113.jpg: 224x256 1 opacity, Done. (0.037s)
# image 1169/1263 /kaggle/covid19_test_images/eb6cabb0b9f2.jpg: 224x256 1 opacity, Done. (0.037s)
# image 1170/1263 /kaggle/covid19_test_images/eb793f1aa7a1.jpg: 224x256 Done. (0.037s)
# image 1171/1263 /kaggle/covid19_test_images/eb9a9b9a0870.jpg: 224x256 1 opacity, Done. (0.038s)
# image 1172/1263 /kaggle/covid19_test_images/ebaebf6b1e02.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1173/1263 /kaggle/covid19_test_images/ebcc9bedfa05.jpg: 224x256 Done. (0.026s)
# image 1174/1263 /kaggle/covid19_test_images/ebf5edbbed2d.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1175/1263 /kaggle/covid19_test_images/ec563919514c.jpg: 256x256 Done. (0.027s)
# image 1176/1263 /kaggle/covid19_test_images/ecb545d2ff15.jpg: 224x256 1 opacity, Done. (0.029s)
# image 1177/1263 /kaggle/covid19_test_images/ecdd379e2a9b.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1178/1263 /kaggle/covid19_test_images/ecebf3314fbd.jpg: 224x256 Done. (0.027s)
# image 1179/1263 /kaggle/covid19_test_images/ed74d42fc445.jpg: 224x256 1 opacity, Done. (0.044s)
# image 1180/1263 /kaggle/covid19_test_images/edd69153435a.jpg: 224x256 Done. (0.040s)
# image 1181/1263 /kaggle/covid19_test_images/ede662a3de87.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1182/1263 /kaggle/covid19_test_images/ee27ca277911.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1183/1263 /kaggle/covid19_test_images/ee2b112cdd91.jpg: 256x256 Done. (0.027s)
# image 1184/1263 /kaggle/covid19_test_images/ee580bf07fa1.jpg: 224x256 Done. (0.026s)
# image 1185/1263 /kaggle/covid19_test_images/eea4c86f42d5.jpg: 224x256 Done. (0.025s)
# image 1186/1263 /kaggle/covid19_test_images/eebfaa5e1a65.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1187/1263 /kaggle/covid19_test_images/eeeb7da65659.jpg: 224x256 Done. (0.026s)
# image 1188/1263 /kaggle/covid19_test_images/eeff73683974.jpg: 256x256 Done. (0.026s)
# image 1189/1263 /kaggle/covid19_test_images/ef25824e7b3a.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1190/1263 /kaggle/covid19_test_images/ef661638c8c0.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1191/1263 /kaggle/covid19_test_images/efcfaa82fcb8.jpg: 224x256 Done. (0.025s)
# image 1192/1263 /kaggle/covid19_test_images/efd8a04416af.jpg: 256x256 Done. (0.026s)
# image 1193/1263 /kaggle/covid19_test_images/eff9f15c7e9b.jpg: 256x256 1 opacity, Done. (0.027s)
# image 1194/1263 /kaggle/covid19_test_images/f016fe5579d7.jpg: 224x256 Done. (0.030s)
# image 1195/1263 /kaggle/covid19_test_images/f02e557a36dc.jpg: 256x256 1 opacity, Done. (0.027s)
# image 1196/1263 /kaggle/covid19_test_images/f038e6d16303.jpg: 224x256 Done. (0.027s)
# image 1197/1263 /kaggle/covid19_test_images/f07e4a04078a.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1198/1263 /kaggle/covid19_test_images/f1774ffc9c4b.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1199/1263 /kaggle/covid19_test_images/f17999420b3f.jpg: 256x256 Done. (0.027s)
# image 1200/1263 /kaggle/covid19_test_images/f1b66ff8f4eb.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1201/1263 /kaggle/covid19_test_images/f1b95b972b74.jpg: 224x256 Done. (0.026s)
# image 1202/1263 /kaggle/covid19_test_images/f2038cb67c83.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1203/1263 /kaggle/covid19_test_images/f2200b845e93.jpg: 256x256 2 opacitys, Done. (0.030s)
# image 1204/1263 /kaggle/covid19_test_images/f2be75ff15ba.jpg: 256x224 1 opacity, Done. (0.028s)
# image 1205/1263 /kaggle/covid19_test_images/f2d98750a22c.jpg: 224x256 1 opacity, Done. (0.029s)
# image 1206/1263 /kaggle/covid19_test_images/f2eaa573742f.jpg: 256x256 Done. (0.026s)
# image 1207/1263 /kaggle/covid19_test_images/f31bb833e467.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1208/1263 /kaggle/covid19_test_images/f3239829a8dc.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1209/1263 /kaggle/covid19_test_images/f34e1aaea8a0.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1210/1263 /kaggle/covid19_test_images/f35d7c728684.jpg: 224x256 Done. (0.026s)
# image 1211/1263 /kaggle/covid19_test_images/f39044d6c511.jpg: 224x256 Done. (0.025s)
# image 1212/1263 /kaggle/covid19_test_images/f3f3ea70d5a7.jpg: 224x256 Done. (0.026s)
# image 1213/1263 /kaggle/covid19_test_images/f49845505871.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1214/1263 /kaggle/covid19_test_images/f504d269be24.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1215/1263 /kaggle/covid19_test_images/f533f5259633.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1216/1263 /kaggle/covid19_test_images/f554169c1277.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 1217/1263 /kaggle/covid19_test_images/f58258eeaa42.jpg: 224x256 Done. (0.028s)
# image 1218/1263 /kaggle/covid19_test_images/f5b45b497add.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1219/1263 /kaggle/covid19_test_images/f625309a6d62.jpg: 256x256 Done. (0.026s)
# image 1220/1263 /kaggle/covid19_test_images/f6ba3df9a8be.jpg: 224x256 Done. (0.026s)
# image 1221/1263 /kaggle/covid19_test_images/f7036442740b.jpg: 224x256 Done. (0.026s)
# image 1222/1263 /kaggle/covid19_test_images/f77d7d1aebab.jpg: 256x256 Done. (0.028s)
# image 1223/1263 /kaggle/covid19_test_images/f785f9c6bbf7.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 1224/1263 /kaggle/covid19_test_images/f78ec02bc8d8.jpg: 224x256 Done. (0.027s)
# image 1225/1263 /kaggle/covid19_test_images/f7cbc735f105.jpg: 256x256 Done. (0.027s)
# image 1226/1263 /kaggle/covid19_test_images/f87f1ab5729e.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1227/1263 /kaggle/covid19_test_images/f8ed7c6111f1.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 1228/1263 /kaggle/covid19_test_images/f900aac4111b.jpg: 256x256 Done. (0.027s)
# image 1229/1263 /kaggle/covid19_test_images/f90deb13b3e2.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1230/1263 /kaggle/covid19_test_images/f91fbbfe4682.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1231/1263 /kaggle/covid19_test_images/f97bf716e365.jpg: 256x256 Done. (0.027s)
# image 1232/1263 /kaggle/covid19_test_images/f99f9714b911.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1233/1263 /kaggle/covid19_test_images/fa0c84ee4577.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1234/1263 /kaggle/covid19_test_images/fa29fd163597.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1235/1263 /kaggle/covid19_test_images/faf630376fa9.jpg: 224x256 Done. (0.027s)
# image 1236/1263 /kaggle/covid19_test_images/fb073252b364.jpg: 224x256 Done. (0.026s)
# image 1237/1263 /kaggle/covid19_test_images/fb1e3b68864d.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1238/1263 /kaggle/covid19_test_images/fbb175d04c3b.jpg: 256x256 Done. (0.027s)
# image 1239/1263 /kaggle/covid19_test_images/fbc094e9276f.jpg: 256x256 Done. (0.026s)
# image 1240/1263 /kaggle/covid19_test_images/fbdb5bff26f2.jpg: 224x256 1 opacity, Done. (0.029s)
# image 1241/1263 /kaggle/covid19_test_images/fbf41ac72bdb.jpg: 224x256 Done. (0.026s)
# image 1242/1263 /kaggle/covid19_test_images/fbf51388c4ff.jpg: 256x256 Done. (0.027s)
# image 1243/1263 /kaggle/covid19_test_images/fc332a1e51c9.jpg: 224x256 Done. (0.027s)
# image 1244/1263 /kaggle/covid19_test_images/fc45a3b144a7.jpg: 192x256 Done. (0.027s)
# image 1245/1263 /kaggle/covid19_test_images/fcc09eaa77c4.jpg: 224x256 Done. (0.028s)
# image 1246/1263 /kaggle/covid19_test_images/fcdb115a918f.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1247/1263 /kaggle/covid19_test_images/fce43e07637a.jpg: 224x256 2 opacitys, Done. (0.031s)
# image 1248/1263 /kaggle/covid19_test_images/fd322d964dc7.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1249/1263 /kaggle/covid19_test_images/fd435a3c012d.jpg: 224x256 2 opacitys, Done. (0.031s)
# image 1250/1263 /kaggle/covid19_test_images/fd65cc14da23.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 1251/1263 /kaggle/covid19_test_images/fd7f440d5444.jpg: 224x256 2 opacitys, Done. (0.043s)
# image 1252/1263 /kaggle/covid19_test_images/fdbaf93d6c5b.jpg: 256x256 Done. (0.043s)
# image 1253/1263 /kaggle/covid19_test_images/fe0cf147b965.jpg: 256x256 Done. (0.037s)
# image 1254/1263 /kaggle/covid19_test_images/fe2c1dc506e7.jpg: 224x256 Done. (0.038s)
# image 1255/1263 /kaggle/covid19_test_images/fe501aa91e43.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1256/1263 /kaggle/covid19_test_images/fe508ca896d7.jpg: 224x256 Done. (0.026s)
# image 1257/1263 /kaggle/covid19_test_images/fe97de4edad5.jpg: 256x256 Done. (0.027s)
# image 1258/1263 /kaggle/covid19_test_images/fec0249d70e4.jpg: 256x256 Done. (0.025s)
# image 1259/1263 /kaggle/covid19_test_images/fed3a460884c.jpg: 224x256 Done. (0.026s)
# image 1260/1263 /kaggle/covid19_test_images/ff5448be90d5.jpg: 224x256 Done. (0.026s)
# image 1261/1263 /kaggle/covid19_test_images/ff88ed1df29b.jpg: 224x256 Done. (0.027s)
# image 1262/1263 /kaggle/covid19_test_images/ffb8115a304c.jpg: 256x256 1 opacity, Done. (0.028s)
# image 1263/1263 /kaggle/covid19_test_images/ffc66893d9ea.jpg: 224x256 Done. (0.026s)
# Results saved to /kaggle/working/output
# 636 labels saved to /kaggle/working/output/labels
# Done. (193.929s)

# %%
# MODEL_PATH = '/kaggle/input/multi-class-model/singlecls_yolovx_c.pt'
# !python /kaggle/input/yolov5code/yolov5-master/detect.py --weights {MODEL_PATH} \
#                                                           --source {TEST_PATH} \
#                                                           --img 256 \
#                                                           --conf-thres 0.357 \
#                                                           --iou-thres 0.5 \
#                                                           --max-det 5 \
#                                                           --save-txt \
#                                                           --save-conf \
#                                                           --project '/kaggle/working/output' \
#                                                           --nosave \
#                                                           --name ""\
#                                                           --exist-ok \
#                                                           --device "0"

# %%
# MODEL_PATH = '/kaggle/input/multi-class-model/singlecls_yolovs_300ep.pt'
# !python /kaggle/input/yolov5code/yolov5-master/detect.py --weights {MODEL_PATH} \
#                                                           --source {TEST_PATH} \
#                                                           --img 640 \
#                                                           --conf-thres 0.066 \
#                                                           --iou-thres 0.5 \
#                                                           --max-det 5 \
#                                                           --save-txt \
#                                                           --save-conf \
#                                                           --project '/kaggle/working/output' \
#                                                           --nosave \
#                                                           --name ""\
#                                                           --exist-ok \
#                                                           --device "0"

# %%
class Data:
    def __init__(self, images, transform=None):
        self.images = images
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):

        file_path = os.path.join(TEST_PATH, self.images[idx].replace("dcm", "jpg"))
        image = cv2.imread(file_path)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']

        return image

# %%
transform = Compose([
            Resize(224, 244),
            Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])
test_dataset = Data(test_meta_df.image_id,transform = transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
#models = os.listdir('/kaggle/input/cnn-model/efficientnet-b0/efficientnet-b0')
#models

# %%
#model_main_path= '/kaggle/input/cnn-model/efficientnet-b0/efficientnet-b0'
model_main_path= '/kaggle/input/cnn-model/resnet18/resnet18'
models = os.listdir(os.path.join(model_main_path, "resnet18"))
models
# Out:
# ['FOLD5_52.37.pth',
#  'FOLD1_52.72.pth',
#  'FOLD2_54.30.pth',
#  'FOLD4_52.41.pth',
#  'FOLD3_49.41.pth']

# %%
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

# %%
# CNN predictions averaged across the 5 folds
from sklearn.decomposition import PCA

LABEL_LIST = ['atypical', 'indeterminate', 'negative', 'typical']

device = "cuda"
CNN_preds = np.zeros((len(test_dataset), len(LABEL_LIST)))
reduced_features = []
pca = PCA(n_components=128)
for model_path in models:
    weights_path = os.path.join(model_main_path, model_path)
    #model = EfficientNet.from_pretrained("efficientnet-b0", weights_path=weights_path, advprop=False, include_top=True, num_classes=len(LABEL_LIST)).to(device)
    
    model=torchvision.models.resnet18(pretrained=False)
    model.avgpool=nn.AdaptiveAvgPool2d(1)
    model.fc=nn.Linear(model.fc.in_features, 4)
    model=model.to(device)
    model.load_state_dict(torch.load(weights_path))
    model.avgpool.register_forward_hook(get_activation('avgpool'))
        
        
    model.eval()
    preds = []
    all_features = []
    tk = tqdm(enumerate(test_loader), total=len(test_loader))
    for i, (images) in tk:
        images = images.to(device).float()
        with torch.no_grad():
            y_preds = model(images)
            #features = model.extract_features(images)
            features = activation['avgpool']
            all_features.append(torch.reshape(features, (features.shape[0], -1)).cpu().numpy())
        preds.append(F.softmax(y_preds).cpu().numpy())
    CNN_preds += np.concatenate(preds)/len(models)
    
    all_features = np.concatenate(all_features)
    reduced_features.append(pca.fit_transform(all_features))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3644308d4d7e> in <module>
#      12     #model = EfficientNet.from_pretrained("efficientnet-b0", weights_path=weights_path, advprop=False, include_top=True, num_classes=len(LABEL_LIST)).to(device)
#      13
# ---> 14     model=torchvision.models.resnet18(pretrained=False)
#      15     model.avgpool=nn.AdaptiveAvgPool2d(1)
#      16     model.fc=nn.Linear(model.fc.in_features, 4)
#
# NameError: name 'torchvision' is not defined

# %%
cnn_preds_df = pd.DataFrame(columns=["id"]+LABEL_LIST)
cnn_preds_df["id"] = [e[:-4]+"_image" for e in test_meta_df["image_id"]]
cnn_preds_df[LABEL_LIST] = CNN_preds

# %%
output_path = '/kaggle/working/output'
ss_df = pd.read_csv("/kaggle/input/siim-covid19-detection/sample_submission.csv")

# %%
#Image-level predictions
image_preds = pd.DataFrame(columns=["id", "PredictionString"])#+LABEL_LIST)
predictions= []
ids = []
meta_data_test = []
m_x1, m_x2, m_y1, m_y2 = 0,0,0,0
for i, (_, row) in enumerate(test_meta_df.iterrows()):
    predictions.append("")
    #if row.id.split("_")[1] == "image":
    ids.append(row.image_id[:-4]+"_image")
    if str(row.image_id[:-4])+".txt" in os.listdir(output_path+'/labels'):
        with open(output_path+'/labels/{}.txt'.format(row.image_id[:-4]), 'r') as f:
            nb = 0
            for line in f:
                nb+=1
                out = line.rsplit("\n")[0].split(" ")
                xc, yc, w, h = float(out[1]), float(out[2]), float(out[3]), float(out[4])
                x1, y1, x2, y2 = (xc-w/2)*row.width, (yc-h/2)*row.height, (xc+w/2)*row.width,( yc+h/2)*row.height
                predictions[-1]+="opacity {:.6f} {} {} {} {} ".format(float(out[5]), int(x1), int(y1), int(x2), int(y2))
                m_x1 += x1
                m_x2 += x2
                m_y1 += y1
                m_y2 += y2
            predictions[-1]=predictions[-1][:-1]
        meta_data_test.append([m_x1/nb, m_x2/nb, m_y1/nb, m_y2/nb, row.height, row.width])
    else:
        predictions[-1]+= "none 1.0 0 0 1 1"
        meta_data_test.append([0,0,0,0, row.height, row.width])
            
meta_data_test = np.array(meta_data_test)        
image_preds["id"] = ids
image_preds["PredictionString"] = predictions

# %%
# LightGBM predictions
import lightgbm as lgb
import re

ml_models = os.path.join(model_main_path,"ML_models") #os.listdir('/kaggle/input/cnn-model/ML_models/ML_models')
ML_preds = np.zeros((len(test_dataset), len(LABEL_LIST)))

for n in range(len(models)):
    r = re.compile(".*Fold.*"+str(n+1))
    ml_path = list(filter(r.match, ml_models))[0]

    df_meta_test = pd.DataFrame(columns = ["f_{}".format(i+1) for i in range(128)], data = reduced_features[n])
    df_meta_test["BBoxArea"] = (meta_data_test[:,1]/meta_data_test[:,5]-meta_data_test[:,0]/meta_data_test[:,5])*(meta_data_test[:,3]/meta_data_test[:,4]-meta_data_test[:,2]//meta_data_test[:,4])
    df_meta_test["AspectRatio"] = (meta_data_test[:,1]-meta_data_test[:,0])/(meta_data_test[:,3]-meta_data_test[:,2])

    clf = lgb.Booster(model_file=os.path.join(model_main_path, ml_path))
    ML_preds +=  clf.predict(df_meta_test)/len(models)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-2e62956d0593> in <module>
#       8 for n in range(len(models)):
#       9     r = re.compile(".*Fold.*"+str(n+1))
# ---> 10     ml_path = list(filter(r.match, ml_models))[0]
#      11
#      12     df_meta_test = pd.DataFrame(columns = ["f_{}".format(i+1) for i in range(128)], data = reduced_features[n])
#
# IndexError: list index out of range

# %%
ml_preds_df = pd.DataFrame(columns=["id"]+LABEL_LIST)
ml_preds_df["id"] = [e[:-4]+"_image" for e in test_meta_df["image_id"]]
ml_preds_df[LABEL_LIST] = ML_preds

# %%
cnnml_preds_df = pd.DataFrame(columns=["id"]+LABEL_LIST)
cnnml_preds_df["id"] = [e[:-4]+"_image" for e in test_meta_df["image_id"]]
cnnml_preds_df[LABEL_LIST] = np.max(np.array([CNN_preds, ML_preds]), axis=0)

# %%
#CNN preds
image_lvl_predictions = pd.merge(image_preds, cnn_preds_df, on="id")
#ML preds
#image_lvl_predictions = pd.merge(image_preds, ml_preds_df, on="id")
#CNN+ML preds
#image_lvl_predictions = pd.merge(image_preds, cnnml_preds_df, on="id")

# %%
#Study-level predictions 
study_preds = pd.DataFrame(columns=["id", "PredictionString"])
predictions= []
ids = []
for i, (_, row) in enumerate(ss_df.iterrows()):
    if row.id.split("_")[1] == "study":
        ids.append(row.id)
        predictions.append("")
        study_imgs = test_meta_df[test_meta_df["study_id"]==row.id.split("_")[0]].image_id.apply(lambda x:x[:-4]+"_image")
        pred_lbls = np.mean(np.array(image_lvl_predictions[image_lvl_predictions["id"].isin(study_imgs)][LABEL_LIST]), axis=0)
        for j in range(len(LABEL_LIST)):
            predictions[-1]+= "{} {:.6f} 0 0 1 1 ".format(LABEL_LIST[j], pred_lbls[j])
        predictions[-1] = predictions[-1][:-1]
study_lvl_predictions =  pd.DataFrame(columns=["id", "PredictionString"])
study_lvl_predictions["id"] = ids
study_lvl_predictions["PredictionString"] = predictions

# %%
# !rm -rf /kaggle/working/output
# !rm -rf /kaggle/working/gdcm

# %%
submission = pd.concat([study_lvl_predictions, image_lvl_predictions[["id", "PredictionString"]]])
submission.to_csv("submission.csv", index=False)

# %%
submission
# Out:
#                       id                                   PredictionString
# 0     00188a671292_study  atypical 0.000000 0 0 1 1 indeterminate 0.0000...
# 1     004bd59708be_study  atypical 0.000000 0 0 1 1 indeterminate 0.0000...
# 2     00508faccd39_study  atypical 0.000000 0 0 1 1 indeterminate 0.0000...
# 3     006486aa80b2_study  atypical 0.000000 0 0 1 1 indeterminate 0.0000...
# 4     00655178fdfc_study  atypical 0.000000 0 0 1 1 indeterminate 0.0000...
# ...                  ...                                                ...
# 1258  a43200bd5ceb_image                                   none 1.0 0 0 1 1
# 1259  37bf83df1b86_image  opacity 0.383566 526 1156 1478 2246 opacity 0....
# 1260  b30d2aef985f_image  opacity 0.358475 2786 1130 3665 2236 opacity 0...
# 1261  a37a362df0ac_image                                   none 1.0 0 0 1 1
# 1262  a0f473f71878_image  opacity 0.421321 2208 96 2812 1250 opacity 0.4...
#
# [2477 rows x 2 columns]
