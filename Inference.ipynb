# %% [markdown]
# **Import necessary packages**

# %%
import os
import cv2
import yaml
import torch
import pandas as pd
from PIL import Image
from torch.utils.data import DataLoader
import numpy as np
import pydicom
from tqdm.notebook import tqdm
from pydicom.pixel_data_handlers.util import apply_voi_lut
import torch.nn.functional as F
from albumentations import Compose, Normalize, Resize, HorizontalFlip, RandomBrightnessContrast, ShiftScaleRotate, IAAAdditiveGaussianNoise, RandomCrop
from albumentations.pytorch import ToTensorV2
from efficientnet_pytorch import EfficientNet

# %%
def dicom2array(path, voi_lut=True, fix_monochrome=True):
    """ Convert dicom file to numpy array 
    
    Args:
        path (str): Path to the dicom file to be converted
        voi_lut (bool): Whether or not VOI LUT is available
        fix_monochrome (bool): Whether or not to apply monochrome fix
        
    Returns:
        Numpy array of the respective dicom file 
        
    """
    # Use the pydicom library to read the dicom file
    dicom = pydicom.read_file(path)
    
    # VOI LUT (if available by DICOM device) is used to 
    # transform raw DICOM data to "human-friendly" view
    if voi_lut:
        data = apply_voi_lut(dicom.pixel_array, dicom)
    else:
        data = dicom.pixel_array
        
    # The XRAY may look inverted
    #   - If we want to fix this we can
    if fix_monochrome and dicom.PhotometricInterpretation == "MONOCHROME1":
        data = np.amax(data) - data
    
    # Normalize the image array and return
    data = data - np.min(data)
    data = data / np.max(data)
    data = (data * 255).astype(np.uint8)
    return data

# %% [markdown]
# **Prepare test dataframe**

# %%
test_meta_df = pd.DataFrame(columns=["image_id", "study_id", "dcm_path", "width", "height"])
images, studies, dcm_path, widths, heights = [], [], [], [], []
tk = tqdm(enumerate(os.listdir(r'D:\Nada\kaggle\Covid19-Detection\data\test')), 
          total=len(os.listdir(r'D:\Nada\kaggle\Covid19-Detection\data\test')))
for _, study in tk:
    for serie in os.listdir(r'D:\Nada\kaggle\Covid19-Detection\data\test\{}'.format(study)):
        for image in os.listdir(r'D:\Nada\kaggle\Covid19-Detection\data\test\{}\{}'.format(study, serie)):
            images.append(image)
            studies.append(study)
            dcm_path.append(r'D:\Nada\kaggle\Covid19-Detection\data\test\{}\{}\{}'.format(study, serie, image))
            arr = dicom2array(dcm_path[-1])
            arr = np.stack((arr, arr, arr), axis=-1)
            widths.append(arr.shape[1])
            heights.append(arr.shape[0])
            
test_meta_df["image_id"]=images
test_meta_df["study_id"]=studies
test_meta_df["dcm_path"]=dcm_path
test_meta_df["width"]=widths
test_meta_df["height"]=heights
# Out:
#   0%|          | 0/1214 [00:00<?, ?it/s]

# %%
TEST_PATH = r'.\yolov5\covid19_test_images'
os.makedirs('./output', exist_ok=True)

# %%
MODEL_PATH = './yolov5/runs/train/single_class_YOLOx-35ep/weights/best.pt'
# !python ./yolov5/detect.py --weights {MODEL_PATH} \
                                                          --source {TEST_PATH} \
                                                          --img 256 \
                                                          --conf-thres 0.357 \
                                                          --iou-thres 0.5 \
                                                          --max-det 5 \
                                                          --save-txt \
                                                          --save-conf \
                                                          --project {'./output'} \
                                                          --nosave \
                                                          --name ""\
                                                          --exist-ok \
                                                          --device "0"
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.357, device='0', exist_ok=True, hide_conf=False, hide_labels=False, img_size=256, iou_thres=0.5, line_thickness=3, max_det=5, name='', nosave=True, project='./output', save_conf=True, save_crop=False, save_txt=True, source='.\\yolov5\\covid19_test_images', update=False, view_img=False, weights=['./yolov5/runs/train/single_class_YOLOx-35ep/weights/best.pt'])
# requirements: requirements.txt not found, check failed.
# image 1/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0026720152f5_image.jpg: 256x256 1 opacity, Done. (0.030s)
# image 2/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\00fc8fc35dc1_image.jpg: 256x224 2 opacitys, Done. (0.028s)
# image 3/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\01c3512eebc3_image.jpg: 256x256 Done. (0.027s)
# image 4/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\01f948f8e544_image.jpg: 256x256 Done. (0.026s)
# image 5/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\022146012034_image.jpg: 256x256 Done. (0.026s)
# image 6/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\02eceb0fc405_image.jpg: 224x256 1 opacity, Done. (0.033s)
# image 7/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\03a778f5a68b_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 8/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\03fa9d7e94a8_image.jpg: 256x256 Done. (0.030s)
# image 9/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\040d0765b661_image.jpg: 256x256 Done. (0.027s)
# image 10/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0418a303883e_image.jpg: 256x256 Done. (0.027s)
# image 11/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\042979d394a1_image.jpg: 224x256 Done. (0.026s)
# image 12/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\04396dd5af2f_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 13/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\045c1e859dfa_image.jpg: 256x256 Done. (0.027s)
# image 14/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\046b1edf6801_image.jpg: 224x256 Done. (0.026s)
# image 15/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\04720d7e4e42_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 16/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\047ba804182b_image.jpg: 256x256 1 opacity, Done. (0.028s)
# image 17/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\049fce8128f9_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 18/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\04a083828fec_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 19/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\04de800ea41a_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 20/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\04f4a36c08a2_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 21/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\05435da60872_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 22/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0562436fde50_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 23/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\059eae61ad15_image.jpg: 224x256 1 opacity, Done. (0.030s)
# image 24/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\05a70a1c16c1_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 25/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\05ab2c886dc1_image.jpg: 256x256 Done. (0.040s)
# image 26/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\05e168e0d636_image.jpg: 256x256 Done. (0.026s)
# image 27/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\05feea9719f5_image.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 28/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\064b37b01cd2_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 29/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\06abdb2562ce_image.jpg: 256x256 1 opacity, Done. (0.028s)
# image 30/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\06df1e2fde68_image.jpg: 224x256 2 opacitys, Done. (0.030s)
# image 31/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\070cbe2d3dbb_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 32/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0718c860f2ee_image.jpg: 224x256 Done. (0.026s)
# image 33/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\079be2a10982_image.jpg: 224x256 Done. (0.025s)
# image 34/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\07c552c36da3.jpg: 224x256 1 opacity, Done. (0.026s)
# image 35/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\07c552c36da3_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 36/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\07db3756ec28_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 37/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\07eb8cf8958a_image.jpg: 256x256 Done. (0.027s)
# image 38/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0821e77a60ed_image.jpg: 224x256 1 opacity, Done. (0.028s)
# image 39/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\087f2e308700_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 40/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\08992bd07010_image.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 41/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\08b12b305a50_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 42/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\08bbffaafbe7_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 43/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\09443dcb865f_image.jpg: 256x256 Done. (0.027s)
# image 44/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\09a38ab5a5bd_image.jpg: 256x256 Done. (0.026s)
# image 45/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\09b64291b1b9_image.jpg: 256x256 Done. (0.026s)
# image 46/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0a0c1312be06_image.jpg: 224x256 1 opacity, Done. (0.028s)
# image 47/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0a3a99612b28_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 48/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0af6a45668be_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 49/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0bbb78f96f46_image.jpg: 256x256 1 opacity, Done. (0.029s)
# image 50/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0be236941397_image.jpg: 224x256 Done. (0.027s)
# image 51/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0c2ad4c7a6c4_image.jpg: 256x256 Done. (0.027s)
# image 52/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0c4d32f6b806_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 53/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0c81b34981b3_image.jpg: 256x256 2 opacitys, Done. (0.029s)
# image 54/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0c8af80ba8cb_image.jpg: 224x256 1 opacity, Done. (0.028s)
# image 55/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0cc69a8f538c_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 56/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0cccb1eca1fc_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 57/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0cea7e93db89_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 58/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0d47ef3e87e4_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 59/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0d4ba5dc4a24_image.jpg: 224x256 Done. (0.025s)
# image 60/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0d50bce86451_image.jpg: 256x256 2 opacitys, Done. (0.032s)
# image 61/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0d617e83e527_image.jpg: 224x256 Done. (0.026s)
# image 62/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0db323463d0a_image.jpg: 256x256 1 opacity, Done. (0.028s)
# image 63/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0dc27df9b1bf_image.jpg: 224x256 1 opacity, Done. (0.028s)
# image 64/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0e97cc4123aa_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 65/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0ed283a366dc_image.jpg: 224x256 Done. (0.025s)
# image 66/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0f01c0517022_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 67/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0f147ee4a61b_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 68/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0f50aabaa314_image.jpg: 224x256 Done. (0.025s)
# image 69/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0f813cc26e33_image.jpg: 224x256 Done. (0.027s)
# image 70/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0feac35cd28b_image.jpg: 224x256 Done. (0.026s)
# image 71/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\0fedf74dc163_image.jpg: 224x256 2 opacitys, Done. (0.030s)
# image 72/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\100316af8a36_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 73/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1047ca1a704c_image.jpg: 224x256 1 opacity, Done. (0.033s)
# image 74/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1078af8ac3b7_image.jpg: 224x256 Done. (0.028s)
# image 75/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1093f305a358_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 76/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\10d3c965a5b4_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 77/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11349660bb1a_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 78/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1137ee93363f_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 79/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\114f7f3baedf_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 80/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11541455ef19_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 81/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1177e1bef164_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 82/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1199fd9f2aba_image.jpg: 256x256 1 opacity, Done. (0.028s)
# image 83/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11abda231924_image.jpg: 224x256 1 opacity, Done. (0.028s)
# image 84/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11b60db4052a_image.jpg: 256x256 Done. (0.027s)
# image 85/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11b8e5179115_image.jpg: 256x256 1 opacity, Done. (0.027s)
# image 86/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11b9ab3af3db_image.jpg: 256x256 Done. (0.026s)
# image 87/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11d59a5488ed_image.jpg: 256x256 Done. (0.026s)
# image 88/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11dbf622932a_image.jpg: 256x224 Done. (0.027s)
# image 89/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11ef0d77a9c9_image.jpg: 224x256 1 opacity, Done. (0.031s)
# image 90/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\11f8052288c7_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 91/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\120ce3e7cd73_image.jpg: 224x256 Done. (0.025s)
# image 92/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\127c2b32dd5d_image.jpg: 256x256 1 opacity, Done. (0.035s)
# image 93/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\129846482a83_image.jpg: 256x256 Done. (0.026s)
# image 94/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\12ae063a0dda_image.jpg: 256x256 2 opacitys, Done. (0.027s)
# image 95/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\12fbfd355d88_image.jpg: 224x256 Done. (0.026s)
# image 96/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1308d8906c2e_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 97/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\130aa9d3716d_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 98/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1359178e428a_image.jpg: 224x256 Done. (0.025s)
# image 99/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\13a28f6783b2_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 100/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\13c550e44b7c_image.jpg: 224x256 Done. (0.025s)
# image 101/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\144c27a2554a_image.jpg: 256x256 Done. (0.027s)
# image 102/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1450e124011a_image.jpg: 256x256 Done. (0.026s)
# image 103/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\14658311d76e_image.jpg: 256x256 2 opacitys, Done. (0.027s)
# image 104/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\14db2ff155f6_image.jpg: 224x256 1 opacity, Done. (0.028s)
# image 105/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\14eb73431579_image.jpg: 224x256 Done. (0.025s)
# image 106/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\14ec6bdb5641_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 107/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\154b6a49ff75_image.jpg: 224x256 Done. (0.025s)
# image 108/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\155f5e326d5e_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 109/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\158cc858a485_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 110/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\159cbf4e41e4_image.jpg: 224x256 Done. (0.026s)
# image 111/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\160cfef3014f_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 112/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\16237f3bc333_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 113/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\164dd63ae571_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 114/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\16972e92e827_image.jpg: 256x256 Done. (0.032s)
# image 115/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\16a0d37747d7_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 116/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\16d5b63ac279_image.jpg: 256x256 Done. (0.028s)
# image 117/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\173c3e37e1f3_image.jpg: 256x256 Done. (0.026s)
# image 118/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\179291642620_image.jpg: 224x256 3 opacitys, Done. (0.027s)
# image 119/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\17ac0fe388c7_image.jpg: 224x256 Done. (0.027s)
# image 120/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\17d708d24ae8_image.jpg: 224x256 Done. (0.025s)
# image 121/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\17e40efa4596_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 122/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\180a5ea482c5_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 123/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\181a2a300bb8_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 124/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1863b31637f6_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 125/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\18a23df4fe99_image.jpg: 224x256 Done. (0.025s)
# image 126/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\18e043b70fda_image.jpg: 224x256 1 opacity, Done. (0.028s)
# image 127/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\18e6a4083920_image.jpg: 224x256 Done. (0.025s)
# image 128/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\198ffac65dac_image.jpg: 224x256 Done. (0.026s)
# image 129/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\19b0d2d65a38_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 130/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\19e9733ee506_image.jpg: 224x256 Done. (0.025s)
# image 131/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1a1722362e19_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 132/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1a330ec81ee3_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 133/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1a4c378605f5_image.jpg: 224x256 Done. (0.025s)
# image 134/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1aa1491c9cd1_image.jpg: 224x256 Done. (0.024s)
# image 135/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1ab561ec5f7e_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 136/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1ade3b5d0699_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 137/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1aff7e4ed470_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 138/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1b0d0622ccea_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 139/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1b282faf0f42_image.jpg: 224x256 2 opacitys, Done. (0.029s)
# image 140/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1b40a20045ee_image.jpg: 256x256 Done. (0.027s)
# image 141/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1b4cf5e0fbe0_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 142/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1b640a2839db_image.jpg: 224x256 Done. (0.026s)
# image 143/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1ba8aa7acf76_image.jpg: 224x256 1 opacity, Done. (0.033s)
# image 144/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1bc8687f938e_image.jpg: 224x256 2 opacitys, Done. (0.037s)
# image 145/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c13336fc8a9_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 146/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c1c48cb66e4_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 147/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c1e9d3f5bab_image.jpg: 256x256 Done. (0.027s)
# image 148/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c47d2fcee72_image.jpg: 224x256 Done. (0.028s)
# image 149/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c5aa8c405c7_image.jpg: 256x256 2 opacitys, Done. (0.029s)
# image 150/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c69c1af9a67_image.jpg: 256x256 Done. (0.026s)
# image 151/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c8df7067e35_image.jpg: 256x256 1 opacity, Done. (0.026s)
# image 152/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c937e2b91a9_image.jpg: 256x256 2 opacitys, Done. (0.027s)
# image 153/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1c9c9f68941e_image.jpg: 224x256 2 opacitys, Done. (0.031s)
# image 154/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1cbd87cb6bf9_image.jpg: 256x256 Done. (0.028s)
# image 155/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1ce9abb861b6_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 156/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1d674718db40_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 157/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1d981fb423e0_image.jpg: 224x256 Done. (0.025s)
# image 158/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1d9a8f9f0eef_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 159/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1dccbb75ffba_image.jpg: 256x256 1 opacity, Done. (0.029s)
# image 160/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1dfed0992998_image.jpg: 256x256 2 opacitys, Done. (0.027s)
# image 161/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1e1734034b0f_image.jpg: 224x256 Done. (0.026s)
# image 162/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1e7429ce2e06_image.jpg: 224x256 1 opacity, Done. (0.032s)
# image 163/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1e9b7b493e47_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 164/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1eae0890a6ad_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 165/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1eb558739c44_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 166/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1ed201489300_image.jpg: 256x256 1 opacity, Done. (0.028s)
# image 167/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\1f49246b305e_image.jpg: 224x256 Done. (0.027s)
# image 168/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\
1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f1b95b972b74_image.jpg: 224x256 Done. (0.025s)
# image 1217/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f2038cb67c83_image.jpg: 224x256 2 opacitys, Done. (0.043s)
# image 1218/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f2200b845e93_image.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 1219/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f2be75ff15ba_image.jpg: 256x224 2 opacitys, Done. (0.028s)
# image 1220/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f2d98750a22c_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1221/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f2eaa573742f_image.jpg: 256x256 Done. (0.028s)
# image 1222/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f31bb833e467_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1223/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f3239829a8dc_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1224/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f34e1aaea8a0_image.jpg: 224x256 1 opacity, Done. (0.039s)
# image 1225/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f35d7c728684_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1226/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f39044d6c511_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1227/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f3f3ea70d5a7_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1228/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f49845505871_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1229/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f504d269be24_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1230/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f533f5259633_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1231/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f554169c1277_image.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 1232/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f58258eeaa42_image.jpg: 224x256 1 opacity, Done. (0.028s)
# image 1233/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f5b45b497add_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1234/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f625309a6d62_image.jpg: 256x256 Done. (0.029s)
# image 1235/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f6ba3df9a8be_image.jpg: 224x256 Done. (0.027s)
# image 1236/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f7036442740b_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1237/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f77d7d1aebab_image.jpg: 256x256 Done. (0.027s)
# image 1238/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f785f9c6bbf7_image.jpg: 224x256 2 opacitys, Done. (0.028s)
# image 1239/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f78ec02bc8d8_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1240/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f7cbc735f105_image.jpg: 256x256 1 opacity, Done. (0.028s)
# image 1241/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f87f1ab5729e_image.jpg: 224x256 1 opacity, Done. (0.030s)
# image 1242/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f8ed7c6111f1_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1243/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f900aac4111b_image.jpg: 256x256 Done. (0.042s)
# image 1244/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f90deb13b3e2_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1245/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f91fbbfe4682_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1246/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f97bf716e365_image.jpg: 256x256 Done. (0.032s)
# image 1247/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\f99f9714b911_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1248/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fa0c84ee4577_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1249/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fa29fd163597_image.jpg: 224x256 Done. (0.027s)
# image 1250/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\faf630376fa9_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 1251/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fb073252b364_image.jpg: 224x256 1 opacity, Done. (0.026s)
# image 1252/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fb1e3b68864d_image.jpg: 224x256 2 opacitys, Done. (0.039s)
# image 1253/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fbb175d04c3b_image.jpg: 256x256 Done. (0.028s)
# image 1254/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fbc094e9276f_image.jpg: 256x256 Done. (0.026s)
# image 1255/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fbdb5bff26f2_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1256/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fbf41ac72bdb_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1257/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fbf51388c4ff_image.jpg: 256x256 Done. (0.026s)
# image 1258/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fc332a1e51c9_image.jpg: 224x256 Done. (0.026s)
# image 1259/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fc45a3b144a7_image.jpg: 192x256 1 opacity, Done. (0.036s)
# image 1260/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fcc09eaa77c4_image.jpg: 224x256 Done. (0.026s)
# image 1261/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fcdb115a918f_image.jpg: 224x256 2 opacitys, Done. (0.031s)
# image 1262/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fce43e07637a_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1263/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fd322d964dc7_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1264/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fd435a3c012d_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1265/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fd65cc14da23_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1266/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fd7f440d5444_image.jpg: 224x256 2 opacitys, Done. (0.026s)
# image 1267/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fdbaf93d6c5b_image.jpg: 256x256 Done. (0.035s)
# image 1268/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fe0cf147b965_image.jpg: 256x256 Done. (0.026s)
# image 1269/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fe2c1dc506e7_image.jpg: 224x256 Done. (0.026s)
# image 1270/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fe501aa91e43_image.jpg: 224x256 2 opacitys, Done. (0.027s)
# image 1271/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fe508ca896d7_image.jpg: 224x256 Done. (0.026s)
# image 1272/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fe97de4edad5_image.jpg: 256x256 Done. (0.027s)
# image 1273/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fec0249d70e4_image.jpg: 256x256 1 opacity, Done. (0.026s)
# image 1274/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\fed3a460884c_image.jpg: 224x256 1 opacity, Done. (0.027s)
# image 1275/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\ff5448be90d5_image.jpg: 224x256 Done. (0.025s)
# image 1276/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\ff88ed1df29b_image.jpg: 224x256 Done. (0.025s)
# image 1277/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\ffb8115a304c_image.jpg: 256x256 2 opacitys, Done. (0.028s)
# image 1278/1278 D:\Nada\kaggle\SIIM-covid19-detection-classification\yolov5\covid19_test_images\ffc66893d9ea_image.jpg: 224x256 Done. (0.027s)
# Results saved to output
# 856 labels saved to output\labels
# Done. (171.222s)
# YOLOv5  9f2ea89 torch 1.7.1 CUDA:0 (GeForce GTX 980 Ti, 6144.0MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients

# %%
class Data:
    def __init__(self, images, transform=None):
        self.images = images
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):

        file_path = os.path.join(TEST_PATH, self.images[idx][:-4]+"_image"+".jpg")
        image = cv2.imread(file_path)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        return image

# %%
transform = Compose([
            Resize(224, 244),
            Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])
test_dataset = Data(test_meta_df.image_id,transform = transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
model_main_path= './CNN/results/EfficientNet0'
models = os.listdir(model_main_path)
models
# Out:
# ['FOLD1_62.23.pth',
#  'FOLD2_63.69.pth',
#  'FOLD3_60.09.pth',
#  'FOLD4_61.42.pth',
#  'FOLD5_61.97.pth',
#  'ML_models',
#  'plots']

# %%
# CNN predictions averaged across the 5 folds
from sklearn.decomposition import PCA

LABEL_LIST = ['atypical', 'indeterminate', 'negative', 'typical']

device = "cuda"
CNN_preds = np.zeros((len(test_dataset), len(LABEL_LIST)))
reduced_features = []
pca = PCA(n_components=128)
for model_path in models:
    if model_path[-3:] == "pth":
        weights_path = os.path.join(model_main_path, model_path)
        model = EfficientNet.from_pretrained("efficientnet-b0", weights_path=weights_path, advprop=False, include_top=True, num_classes=len(LABEL_LIST)).to(device)

        model.eval()
        preds = []
        all_features = []
        tk = tqdm(enumerate(test_loader), total=len(test_loader))
        for i, (images) in tk:
            images = images.to(device).float()
            with torch.no_grad():
                y_preds = model(images)
                features = model.extract_features(images)
                all_features.append(torch.reshape(features, (features.shape[0], -1)).cpu().numpy())
            preds.append(F.softmax(y_preds).cpu().numpy())
        CNN_preds += np.concatenate(preds)/len(models)

        all_features = np.concatenate(all_features)
        reduced_features.append(pca.fit_transform(all_features))
# Out:
# Loaded pretrained weights for efficientnet-b0
#   0%|          | 0/20 [00:00<?, ?it/s]
# C:\Users\baili\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Loaded pretrained weights for efficientnet-b0
#   0%|          | 0/20 [00:00<?, ?it/s]
# C:\Users\baili\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Loaded pretrained weights for efficientnet-b0
#   0%|          | 0/20 [00:00<?, ?it/s]
# C:\Users\baili\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Loaded pretrained weights for efficientnet-b0
#   0%|          | 0/20 [00:00<?, ?it/s]
# C:\Users\baili\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Loaded pretrained weights for efficientnet-b0
#   0%|          | 0/20 [00:00<?, ?it/s]
# C:\Users\baili\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-49-f78d7a89ebcf> in <module>
#      10 for model_path in models:
#      11     weights_path = os.path.join(model_main_path, model_path)
# ---> 12     model = EfficientNet.from_pretrained("efficientnet-b0", weights_path=weights_path, advprop=False, include_top=True, num_classes=len(LABEL_LIST)).to(device)
#      13
#      14     model.eval()
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\efficientnet_pytorch\model.py in from_pretrained(cls, model_name, weights_path, advprop, in_channels, num_classes, **override_params)
#     378         load_pretrained_weights(model, model_name, weights_path=weights_path,
#     379                                 #load_fc=(num_classes == 1000), advprop=advprop)
# --> 380                                 load_fc=(num_classes == 1000) and model._global_params.include_top, advprop=advprop)
#     381         model._change_in_channels(in_channels)
#     382         return model
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\efficientnet_pytorch\utils.py in load_pretrained_weights(model, model_name, weights_path, load_fc, advprop, verbose)
#     596     """
#     597     if isinstance(weights_path, str):
# --> 598         state_dict = torch.load(weights_path)
#     599     else:
#     600         # AutoAugment or Advprop (different preprocessing)
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     579         pickle_load_args['encoding'] = 'utf-8'
#     580
# --> 581     with _open_file_like(f, 'rb') as opened_file:
#     582         if _is_zipfile(opened_file):
#     583             # The zipfile reader is going to advance the current file position.
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# PermissionError: [Errno 13] Permission denied: './CNN/results/EfficientNet0\\ML_models'

# %%
cnn_preds_df = pd.DataFrame(columns=["id"]+LABEL_LIST)
cnn_preds_df["id"] = [e[:-4]+"_image" for e in test_meta_df["image_id"]]
cnn_preds_df[LABEL_LIST] = CNN_preds

# %%
output_path = './output'
ss_df = pd.read_csv("./input/sample_submission.csv")

# %%
#Image-level predictions
image_preds = pd.DataFrame(columns=["id", "PredictionString"])#+LABEL_LIST)
predictions= []
ids = []
meta_data_test = []
m_x1, m_x2, m_y1, m_y2 = 0,0,0,0
for i, (_, row) in enumerate(test_meta_df.iterrows()):
    predictions.append("")
    #if row.id.split("_")[1] == "image":
    ids.append(row.image_id[:-4]+"_image")
    if str(row.image_id[:-4])+"_image.txt" in os.listdir(output_path+'/labels'):
        with open(output_path+'/labels/{}.txt'.format(row.image_id[:-4]+"_image"), 'r') as f:
            nb = 0
            for line in f:
                nb+=1
                out = line.rsplit("\n")[0].split(" ")
                xc, yc, w, h = float(out[1]), float(out[2]), float(out[3]), float(out[4])
                x1, y1, x2, y2 = (xc-w/2)*row.width, (yc-h/2)*row.height, (xc+w/2)*row.width,( yc+h/2)*row.height
                predictions[-1]+="opacity {:.6f} {} {} {} {} ".format(float(out[5]), int(x1), int(y1), int(x2), int(y2))
                m_x1 += x1
                m_x2 += x2
                m_y1 += y1
                m_y2 += y2
            predictions[-1]=predictions[-1][:-1]
        meta_data_test.append([m_x1/nb, m_x2/nb, m_y1/nb, m_y2/nb, row.height, row.width])
    else:
        predictions[-1]+= "none 1.0 0 0 1 1"
        meta_data_test.append([0,0,0,0, row.height, row.width])
            
meta_data_test = np.array(meta_data_test)        
image_preds["id"] = ids
image_preds["PredictionString"] = predictions

# %%
# LightGBM predictions
import lightgbm as lgb
import re

ml_models = os.listdir(os.path.join(model_main_path,"ML_models"))
ML_preds = np.zeros((len(test_dataset), len(LABEL_LIST)))

for n in range(5):
    r = re.compile(".*Fold.*"+str(n+1))
    ml_path = list(filter(r.match, ml_models))[0]

    df_meta_test = pd.DataFrame(columns = ["f_{}".format(i+1) for i in range(128)], data = reduced_features[n])
    df_meta_test["BBoxArea"] = (meta_data_test[:,1]/meta_data_test[:,5]-meta_data_test[:,0]/meta_data_test[:,5])*(meta_data_test[:,3]/meta_data_test[:,4]-meta_data_test[:,2]//meta_data_test[:,4])
    df_meta_test["AspectRatio"] = (meta_data_test[:,1]-meta_data_test[:,0])/(meta_data_test[:,3]-meta_data_test[:,2])

    clf = lgb.Booster(model_file=os.path.join(os.path.join(model_main_path,"ML_models"), ml_path))
    ML_preds +=  clf.predict(df_meta_test)/len(models)
# Out:
# C:\Users\baili\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in true_divide

# %%
ml_preds_df = pd.DataFrame(columns=["id"]+LABEL_LIST)
ml_preds_df["id"] = [e[:-4]+"_image" for e in test_meta_df["image_id"]]
ml_preds_df[LABEL_LIST] = ML_preds

# %%
cnnml_preds_df = pd.DataFrame(columns=["id"]+LABEL_LIST)
cnnml_preds_df["id"] = [e[:-4]+"_image" for e in test_meta_df["image_id"]]
cnnml_preds_df[LABEL_LIST] = np.max(np.array([CNN_preds, ML_preds]), axis=0)

# %%
#CNN preds
image_lvl_predictions = pd.merge(image_preds, cnn_preds_df, on="id")

#ML preds
#image_lvl_predictions = pd.merge(image_preds, ml_preds_df, on="id")

#CNN+ML preds
#image_lvl_predictions = pd.merge(image_preds, cnnml_preds_df, on="id")

# %%
#Study-level predictions 
study_preds = pd.DataFrame(columns=["id", "PredictionString"])
predictions= []
ids = []
for i, (_, row) in enumerate(ss_df.iterrows()):
    if row.id.split("_")[1] == "study":
        ids.append(row.id)
        predictions.append("")
        study_imgs = test_meta_df[test_meta_df["study_id"]==row.id.split("_")[0]].image_id.apply(lambda x:x[:-4]+"_image")
        pred_lbls = np.mean(np.array(image_lvl_predictions[image_lvl_predictions["id"].isin(study_imgs)][LABEL_LIST]), axis=0)
        for j in range(len(LABEL_LIST)):
            predictions[-1]+= "{} {:.6f} 0 0 1 1 ".format(LABEL_LIST[j], pred_lbls[j])
        predictions[-1] = predictions[-1][:-1]
study_lvl_predictions =  pd.DataFrame(columns=["id", "PredictionString"])
study_lvl_predictions["id"] = ids
study_lvl_predictions["PredictionString"] = predictions

# %%
submission = pd.concat([study_lvl_predictions, image_lvl_predictions[["id", "PredictionString"]]])
submission.to_csv("predictions.csv", index=False)

# %%
submission
# Out:
#                       id                                   PredictionString
# 0     00188a671292_study  atypical 0.198247 0 0 1 1 indeterminate 0.1925...
# 1     004bd59708be_study  atypical 0.150155 0 0 1 1 indeterminate 0.1923...
# 2     00508faccd39_study  atypical 0.176205 0 0 1 1 indeterminate 0.1821...
# 3     006486aa80b2_study  atypical 0.191835 0 0 1 1 indeterminate 0.1746...
# 4     00655178fdfc_study  atypical 0.178840 0 0 1 1 indeterminate 0.1740...
# ...                  ...                                                ...
# 1258  064b37b01cd2_image                opacity 0.373535 2608 898 3553 3110
# 1259  02eceb0fc405_image               opacity 0.535645 1205 1569 1812 2191
# 1260  16a0d37747d7_image  opacity 0.502930 925 719 2219 2875 opacity 0.6...
# 1261  aa55fc6c616c_image                                   none 1.0 0 0 1 1
# 1262  36be4f943382_image                 opacity 0.375244 548 488 1440 2251
#
# [2477 rows x 2 columns]
